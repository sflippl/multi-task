# %%
import torch
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
def plot_metric_across_alphas(run_data, metric_name, type, alphas, seeds):
    """
    Plots a specific metric for all alphas with error bars and removed top/right borders.
    """
    fig, ax = plt.subplots(figsize=(10, 6))
    
    colors = plt.cm.get_cmap('tab10', len(alphas))
   
    for i, alpha in enumerate(alphas):
        train_aux_values = []
        for seed in seeds:
            data_matrix = run_data[metric_name][alpha]
            data_dict = data_matrix[seed].item()
            train_aux_values.append(data_dict[type])
                
        # Calculate statistics
        min_len = min(len(arr) for arr in train_aux_values)
        truncated_matrix = np.stack([arr[:min_len] for arr in train_aux_values])

        mean_vector = np.mean(truncated_matrix, axis=0)
        std_vector = np.std(truncated_matrix, axis=0)
        epochs = np.arange(len(mean_vector))
        color = colors(i)
        
        # Plot with error bars instead of fill_between
        # 'errorevery=5' prevents the plot from becoming too cluttered
        ax.errorbar(
            epochs, 
            mean_vector, 
            yerr=std_vector, 
            label=f'α={alpha}', 
            color=color, 
            linewidth=2,
            capsize=3,
            errorevery=1, 
            alpha=0.8
        )

    # --- Styling ---
    # Remove top and right spines (borders)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    ax.set_title(f'Mean {metric_name.capitalize()} {type.capitalize()} across Seeds', fontsize=14)
    ax.set_xlabel('Epochs')
    ax.set_ylabel(metric_name.capitalize())
    ax.legend(title="Alpha Values", frameon=False) # Removed frame to match clean style
    
    plt.tight_layout()
    plt.show()
# --- Example Usage ---
# plot_metric_across_alphas(run_data, 'accs', alphas=[0.1, 0.5, 1.0])
# plot_metric_across_alphas(run_data, 'losses', alphas=[0.1, 0.5, 1.0])

# %%
    
import torch
import numpy as np
from pathlib import Path


seeds = list(range(30))
alphas=[0.01,0.1,0.5,1.0,2,5,10]
base_path = Path("/nfs/nhome/live/cdomine/old_sam/multi-task/data/cifar/pretrain_fr_block_123/")
run_data = {
    'losses': {a: [] for a in alphas},
    'accs': {a: [] for a in alphas},
    'models': {a: [] for a in alphas},
    'l2_regs': {a: [] for a in alphas}
}

for alpha in alphas:
    for seed in seeds:
        folder_name = (
            f"random_seed={seed}"
            f"--alpha_policy=fr_block_123--alpha={alpha}"
        )
        
        dir_path = base_path / folder_name
        if dir_path.exists():
            # Load and append data to the lists
            if (dir_path / "losses.npy").exists():
                run_data['losses'][alpha].append(np.load(dir_path / "losses.npy",allow_pickle=True))
                print(f"✅ Loaded Seed {seed}, Alpha {alpha}, Losses")
            if (dir_path / "accs.npy").exists():
                run_data['accs'][alpha].append(np.load(dir_path / "accs.npy",allow_pickle=True))
                print(f"✅ Loaded Seed {seed}, Alpha {alpha}, Accs")
        else:
            print(f"Missing directory: {folder_name}")

# Convert lists to numpy arrays for easier math later: run_data['accs'][0.1] will be (10, epochs)
for metric in ['losses', 'accs','l2_regs']:
    for alpha in alphas:
        if run_data[metric][alpha]:
            run_data[metric][alpha] = np.array(run_data[metric][alpha])
# Out:
# ✅ Loaded Seed 0, Alpha 0.01, Losses
# ✅ Loaded Seed 0, Alpha 0.01, Accs
# ✅ Loaded Seed 1, Alpha 0.01, Losses
# ✅ Loaded Seed 1, Alpha 0.01, Accs
# ✅ Loaded Seed 2, Alpha 0.01, Losses
# ✅ Loaded Seed 2, Alpha 0.01, Accs
# ✅ Loaded Seed 3, Alpha 0.01, Losses
# ✅ Loaded Seed 3, Alpha 0.01, Accs
# ✅ Loaded Seed 4, Alpha 0.01, Losses
# ✅ Loaded Seed 4, Alpha 0.01, Accs
# ✅ Loaded Seed 5, Alpha 0.01, Losses
# ✅ Loaded Seed 5, Alpha 0.01, Accs
# ✅ Loaded Seed 6, Alpha 0.01, Losses
# ✅ Loaded Seed 6, Alpha 0.01, Accs
# ✅ Loaded Seed 7, Alpha 0.01, Losses
# ✅ Loaded Seed 7, Alpha 0.01, Accs
# ✅ Loaded Seed 8, Alpha 0.01, Losses
# ✅ Loaded Seed 8, Alpha 0.01, Accs
# ✅ Loaded Seed 9, Alpha 0.01, Losses
# ✅ Loaded Seed 9, Alpha 0.01, Accs
# ✅ Loaded Seed 10, Alpha 0.01, Losses
# ✅ Loaded Seed 10, Alpha 0.01, Accs
# ✅ Loaded Seed 11, Alpha 0.01, Losses
# ✅ Loaded Seed 11, Alpha 0.01, Accs
# ✅ Loaded Seed 12, Alpha 0.01, Losses
# ✅ Loaded Seed 12, Alpha 0.01, Accs
# ✅ Loaded Seed 13, Alpha 0.01, Losses
# ✅ Loaded Seed 13, Alpha 0.01, Accs
# ✅ Loaded Seed 14, Alpha 0.01, Losses
# ✅ Loaded Seed 14, Alpha 0.01, Accs
# ✅ Loaded Seed 15, Alpha 0.01, Losses
# ✅ Loaded Seed 15, Alpha 0.01, Accs
# ✅ Loaded Seed 16, Alpha 0.01, Losses
# ✅ Loaded Seed 16, Alpha 0.01, Accs
# ✅ Loaded Seed 17, Alpha 0.01, Losses
# ✅ Loaded Seed 17, Alpha 0.01, Accs
# ✅ Loaded Seed 18, Alpha 0.01, Losses
# ✅ Loaded Seed 18, Alpha 0.01, Accs
# ✅ Loaded Seed 19, Alpha 0.01, Losses
# ✅ Loaded Seed 19, Alpha 0.01, Accs
# ✅ Loaded Seed 20, Alpha 0.01, Losses
# ✅ Loaded Seed 20, Alpha 0.01, Accs
# ✅ Loaded Seed 21, Alpha 0.01, Losses
# ✅ Loaded Seed 21, Alpha 0.01, Accs
# ✅ Loaded Seed 22, Alpha 0.01, Losses
# ✅ Loaded Seed 22, Alpha 0.01, Accs
# ✅ Loaded Seed 23, Alpha 0.01, Losses
# ✅ Loaded Seed 23, Alpha 0.01, Accs
# ✅ Loaded Seed 24, Alpha 0.01, Losses
# ✅ Loaded Seed 24, Alpha 0.01, Accs
# ✅ Loaded Seed 25, Alpha 0.01, Losses
# ✅ Loaded Seed 25, Alpha 0.01, Accs
# ✅ Loaded Seed 26, Alpha 0.01, Losses
# ✅ Loaded Seed 26, Alpha 0.01, Accs
# ✅ Loaded Seed 27, Alpha 0.01, Losses
# ✅ Loaded Seed 27, Alpha 0.01, Accs
# ✅ Loaded Seed 28, Alpha 0.01, Losses
# ✅ Loaded Seed 28, Alpha 0.01, Accs
# ✅ Loaded Seed 29, Alpha 0.01, Losses
# ✅ Loaded Seed 29, Alpha 0.01, Accs
# ✅ Loaded Seed 0, Alpha 0.1, Losses
# ✅ Loaded Seed 0, Alpha 0.1, Accs
# ✅ Loaded Seed 1, Alpha 0.1, Losses
# ✅ Loaded Seed 1, Alpha 0.1, Accs
# ✅ Loaded Seed 2, Alpha 0.1, Losses
# ✅ Loaded Seed 2, Alpha 0.1, Accs
# ✅ Loaded Seed 3, Alpha 0.1, Losses
# ✅ Loaded Seed 3, Alpha 0.1, Accs
# ✅ Loaded Seed 4, Alpha 0.1, Losses
# ✅ Loaded Seed 4, Alpha 0.1, Accs
# ✅ Loaded Seed 5, Alpha 0.1, Losses
# ✅ Loaded Seed 5, Alpha 0.1, Accs
# ✅ Loaded Seed 6, Alpha 0.1, Losses
# ✅ Loaded Seed 6, Alpha 0.1, Accs
# ✅ Loaded Seed 7, Alpha 0.1, Losses
# ✅ Loaded Seed 7, Alpha 0.1, Accs
# ✅ Loaded Seed 8, Alpha 0.1, Losses
# ✅ Loaded Seed 8, Alpha 0.1, Accs
# ✅ Loaded Seed 9, Alpha 0.1, Losses
# ✅ Loaded Seed 9, Alpha 0.1, Accs
# ✅ Loaded Seed 10, Alpha 0.1, Losses
# ✅ Loaded Seed 10, Alpha 0.1, Accs
# ✅ Loaded Seed 11, Alpha 0.1, Losses
# ✅ Loaded Seed 11, Alpha 0.1, Accs
# ✅ Loaded Seed 12, Alpha 0.1, Losses
# ✅ Loaded Seed 12, Alpha 0.1, Accs
# ✅ Loaded Seed 13, Alpha 0.1, Losses
# ✅ Loaded Seed 13, Alpha 0.1, Accs
# ✅ Loaded Seed 14, Alpha 0.1, Losses
# ✅ Loaded Seed 14, Alpha 0.1, Accs
# ✅ Loaded Seed 15, Alpha 0.1, Losses
# ✅ Loaded Seed 15, Alpha 0.1, Accs
# ✅ Loaded Seed 16, Alpha 0.1, Losses
# ✅ Loaded Seed 16, Alpha 0.1, Accs
# ✅ Loaded Seed 17, Alpha 0.1, Losses
# ✅ Loaded Seed 17, Alpha 0.1, Accs
# ✅ Loaded Seed 18, Alpha 0.1, Losses
# ✅ Loaded Seed 18, Alpha 0.1, Accs
# ✅ Loaded Seed 19, Alpha 0.1, Losses
# ✅ Loaded Seed 19, Alpha 0.1, Accs
# ✅ Loaded Seed 20, Alpha 0.1, Losses
# ✅ Loaded Seed 20, Alpha 0.1, Accs
# ✅ Loaded Seed 21, Alpha 0.1, Losses
# ✅ Loaded Seed 21, Alpha 0.1, Accs
# ✅ Loaded Seed 22, Alpha 0.1, Losses
# ✅ Loaded Seed 22, Alpha 0.1, Accs
# ✅ Loaded Seed 23, Alpha 0.1, Losses
# ✅ Loaded Seed 23, Alpha 0.1, Accs
# ✅ Loaded Seed 24, Alpha 0.1, Losses
# ✅ Loaded Seed 24, Alpha 0.1, Accs
# ✅ Loaded Seed 25, Alpha 0.1, Losses
# ✅ Loaded Seed 25, Alpha 0.1, Accs
# ✅ Loaded Seed 26, Alpha 0.1, Losses
# ✅ Loaded Seed 26, Alpha 0.1, Accs
# ✅ Loaded Seed 27, Alpha 0.1, Losses
# ✅ Loaded Seed 27, Alpha 0.1, Accs
# ✅ Loaded Seed 28, Alpha 0.1, Losses
# ✅ Loaded Seed 28, Alpha 0.1, Accs
# ✅ Loaded Seed 29, Alpha 0.1, Losses
# ✅ Loaded Seed 29, Alpha 0.1, Accs
# ✅ Loaded Seed 0, Alpha 0.5, Losses
# ✅ Loaded Seed 0, Alpha 0.5, Accs
# ✅ Loaded Seed 1, Alpha 0.5, Losses
# ✅ Loaded Seed 1, Alpha 0.5, Accs
# ✅ Loaded Seed 2, Alpha 0.5, Losses
# ✅ Loaded Seed 2, Alpha 0.5, Accs
# ✅ Loaded Seed 3, Alpha 0.5, Losses
# ✅ Loaded Seed 3, Alpha 0.5, Accs
# ✅ Loaded Seed 4, Alpha 0.5, Losses
# ✅ Loaded Seed 4, Alpha 0.5, Accs
# ✅ Loaded Seed 5, Alpha 0.5, Losses
# ✅ Loaded Seed 5, Alpha 0.5, Accs
# ✅ Loaded Seed 6, Alpha 0.5, Losses
# ✅ Loaded Seed 6, Alpha 0.5, Accs
# ✅ Loaded Seed 7, Alpha 0.5, Losses
# ✅ Loaded Seed 7, Alpha 0.5, Accs
# ✅ Loaded Seed 8, Alpha 0.5, Losses
# ✅ Loaded Seed 8, Alpha 0.5, Accs
# ✅ Loaded Seed 9, Alpha 0.5, Losses
# ✅ Loaded Seed 9, Alpha 0.5, Accs
# ✅ Loaded Seed 10, Alpha 0.5, Losses
# ✅ Loaded Seed 10, Alpha 0.5, Accs
# ✅ Loaded Seed 11, Alpha 0.5, Losses
# ✅ Loaded Seed 11, Alpha 0.5, Accs
# ✅ Loaded Seed 12, Alpha 0.5, Losses
# ✅ Loaded Seed 12, Alpha 0.5, Accs
# ✅ Loaded Seed 13, Alpha 0.5, Losses
# ✅ Loaded Seed 13, Alpha 0.5, Accs
# ✅ Loaded Seed 14, Alpha 0.5, Losses
# ✅ Loaded Seed 14, Alpha 0.5, Accs
# ✅ Loaded Seed 15, Alpha 0.5, Losses
# ✅ Loaded Seed 15, Alpha 0.5, Accs
# ✅ Loaded Seed 16, Alpha 0.5, Losses
# ✅ Loaded Seed 16, Alpha 0.5, Accs
# ✅ Loaded Seed 17, Alpha 0.5, Losses
# ✅ Loaded Seed 17, Alpha 0.5, Accs
# ✅ Loaded Seed 18, Alpha 0.5, Losses
# ✅ Loaded Seed 18, Alpha 0.5, Accs
# ✅ Loaded Seed 19, Alpha 0.5, Losses
# ✅ Loaded Seed 19, Alpha 0.5, Accs
# ✅ Loaded Seed 20, Alpha 0.5, Losses
# ✅ Loaded Seed 20, Alpha 0.5, Accs
# ✅ Loaded Seed 21, Alpha 0.5, Losses
# ✅ Loaded Seed 21, Alpha 0.5, Accs
# ✅ Loaded Seed 22, Alpha 0.5, Losses
# ✅ Loaded Seed 22, Alpha 0.5, Accs
# ✅ Loaded Seed 23, Alpha 0.5, Losses
# ✅ Loaded Seed 23, Alpha 0.5, Accs
# ✅ Loaded Seed 24, Alpha 0.5, Losses
# ✅ Loaded Seed 24, Alpha 0.5, Accs
# ✅ Loaded Seed 25, Alpha 0.5, Losses
# ✅ Loaded Seed 25, Alpha 0.5, Accs
# ✅ Loaded Seed 26, Alpha 0.5, Losses
# ✅ Loaded Seed 26, Alpha 0.5, Accs
# ✅ Loaded Seed 27, Alpha 0.5, Losses
# ✅ Loaded Seed 27, Alpha 0.5, Accs
# ✅ Loaded Seed 28, Alpha 0.5, Losses
# ✅ Loaded Seed 28, Alpha 0.5, Accs
# ✅ Loaded Seed 29, Alpha 0.5, Losses
# ✅ Loaded Seed 29, Alpha 0.5, Accs
# ✅ Loaded Seed 0, Alpha 1.0, Losses
# ✅ Loaded Seed 0, Alpha 1.0, Accs
# ✅ Loaded Seed 1, Alpha 1.0, Losses
# ✅ Loaded Seed 1, Alpha 1.0, Accs
# ✅ Loaded Seed 2, Alpha 1.0, Losses
# ✅ Loaded Seed 2, Alpha 1.0, Accs
# ✅ Loaded Seed 3, Alpha 1.0, Losses
# ✅ Loaded Seed 3, Alpha 1.0, Accs
# ✅ Loaded Seed 4, Alpha 1.0, Losses
# ✅ Loaded Seed 4, Alpha 1.0, Accs
# ✅ Loaded Seed 5, Alpha 1.0, Losses
# ✅ Loaded Seed 5, Alpha 1.0, Accs
# ✅ Loaded Seed 6, Alpha 1.0, Losses
# ✅ Loaded Seed 6, Alpha 1.0, Accs
# ✅ Loaded Seed 7, Alpha 1.0, Losses
# ✅ Loaded Seed 7, Alpha 1.0, Accs
# ✅ Loaded Seed 8, Alpha 1.0, Losses
# ✅ Loaded Seed 8, Alpha 1.0, Accs
# ✅ Loaded Seed 9, Alpha 1.0, Losses
# ✅ Loaded Seed 9, Alpha 1.0, Accs
# ✅ Loaded Seed 10, Alpha 1.0, Losses
# ✅ Loaded Seed 10, Alpha 1.0, Accs
# ✅ Loaded Seed 11, Alpha 1.0, Losses
# ✅ Loaded Seed 11, Alpha 1.0, Accs
# ✅ Loaded Seed 12, Alpha 1.0, Losses
# ✅ Loaded Seed 12, Alpha 1.0, Accs
# ✅ Loaded Seed 13, Alpha 1.0, Losses
# ✅ Loaded Seed 13, Alpha 1.0, Accs
# ✅ Loaded Seed 14, Alpha 1.0, Losses
# ✅ Loaded Seed 14, Alpha 1.0, Accs
# ✅ Loaded Seed 15, Alpha 1.0, Losses
# ✅ Loaded Seed 15, Alpha 1.0, Accs
# ✅ Loaded Seed 16, Alpha 1.0, Losses
# ✅ Loaded Seed 16, Alpha 1.0, Accs
# ✅ Loaded Seed 17, Alpha 1.0, Losses
# ✅ Loaded Seed 17, Alpha 1.0, Accs
# ✅ Loaded Seed 18, Alpha 1.0, Losses
# ✅ Loaded Seed 18, Alpha 1.0, Accs
# ✅ Loaded Seed 19, Alpha 1.0, Losses
# ✅ Loaded Seed 19, Alpha 1.0, Accs
# ✅ Loaded Seed 20, Alpha 1.0, Losses
# ✅ Loaded Seed 20, Alpha 1.0, Accs
# ✅ Loaded Seed 21, Alpha 1.0, Losses
# ✅ Loaded Seed 21, Alpha 1.0, Accs
# ✅ Loaded Seed 22, Alpha 1.0, Losses
# ✅ Loaded Seed 22, Alpha 1.0, Accs
# ✅ Loaded Seed 23, Alpha 1.0, Losses
# ✅ Loaded Seed 23, Alpha 1.0, Accs
# ✅ Loaded Seed 24, Alpha 1.0, Losses
# ✅ Loaded Seed 24, Alpha 1.0, Accs
# ✅ Loaded Seed 25, Alpha 1.0, Losses
# ✅ Loaded Seed 25, Alpha 1.0, Accs
# ✅ Loaded Seed 26, Alpha 1.0, Losses
# ✅ Loaded Seed 26, Alpha 1.0, Accs
# ✅ Loaded Seed 27, Alpha 1.0, Losses
# ✅ Loaded Seed 27, Alpha 1.0, Accs
# ✅ Loaded Seed 28, Alpha 1.0, Losses
# ✅ Loaded Seed 28, Alpha 1.0, Accs
# ✅ Loaded Seed 29, Alpha 1.0, Losses
# ✅ Loaded Seed 29, Alpha 1.0, Accs
# ✅ Loaded Seed 0, Alpha 2, Losses
# ✅ Loaded Seed 0, Alpha 2, Accs
# ✅ Loaded Seed 1, Alpha 2, Losses
# ✅ Loaded Seed 1, Alpha 2, Accs
# ✅ Loaded Seed 2, Alpha 2, Losses
# ✅ Loaded Seed 2, Alpha 2, Accs
# ✅ Loaded Seed 3, Alpha 2, Losses
# ✅ Loaded Seed 3, Alpha 2, Accs
# ✅ Loaded Seed 4, Alpha 2, Losses
# ✅ Loaded Seed 4, Alpha 2, Accs
# ✅ Loaded Seed 5, Alpha 2, Losses
# ✅ Loaded Seed 5, Alpha 2, Accs
# ✅ Loaded Seed 6, Alpha 2, Losses
# ✅ Loaded Seed 6, Alpha 2, Accs
# ✅ Loaded Seed 7, Alpha 2, Losses
# ✅ Loaded Seed 7, Alpha 2, Accs
# ✅ Loaded Seed 8, Alpha 2, Losses
# ✅ Loaded Seed 8, Alpha 2, Accs
# ✅ Loaded Seed 9, Alpha 2, Losses
# ✅ Loaded Seed 9, Alpha 2, Accs
# ✅ Loaded Seed 10, Alpha 2, Losses
# ✅ Loaded Seed 10, Alpha 2, Accs
# ✅ Loaded Seed 11, Alpha 2, Losses
# ✅ Loaded Seed 11, Alpha 2, Accs
# ✅ Loaded Seed 12, Alpha 2, Losses
# ✅ Loaded Seed 12, Alpha 2, Accs
# ✅ Loaded Seed 13, Alpha 2, Losses
# ✅ Loaded Seed 13, Alpha 2, Accs
# ✅ Loaded Seed 14, Alpha 2, Losses
# ✅ Loaded Seed 14, Alpha 2, Accs
# ✅ Loaded Seed 15, Alpha 2, Losses
# ✅ Loaded Seed 15, Alpha 2, Accs
# ✅ Loaded Seed 16, Alpha 2, Losses
# ✅ Loaded Seed 16, Alpha 2, Accs
# ✅ Loaded Seed 17, Alpha 2, Losses
# ✅ Loaded Seed 17, Alpha 2, Accs
# ✅ Loaded Seed 18, Alpha 2, Losses
# ✅ Loaded Seed 18, Alpha 2, Accs
# ✅ Loaded Seed 19, Alpha 2, Losses
# ✅ Loaded Seed 19, Alpha 2, Accs
# ✅ Loaded Seed 20, Alpha 2, Losses
# ✅ Loaded Seed 20, Alpha 2, Accs
# ✅ Loaded Seed 21, Alpha 2, Losses
# ✅ Loaded Seed 21, Alpha 2, Accs
# ✅ Loaded Seed 22, Alpha 2, Losses
# ✅ Loaded Seed 22, Alpha 2, Accs
# ✅ Loaded Seed 23, Alpha 2, Losses
# ✅ Loaded Seed 23, Alpha 2, Accs
# ✅ Loaded Seed 24, Alpha 2, Losses
# ✅ Loaded Seed 24, Alpha 2, Accs
# ✅ Loaded Seed 25, Alpha 2, Losses
# ✅ Loaded Seed 25, Alpha 2, Accs
# ✅ Loaded Seed 26, Alpha 2, Losses
# ✅ Loaded Seed 26, Alpha 2, Accs
# ✅ Loaded Seed 27, Alpha 2, Losses
# ✅ Loaded Seed 27, Alpha 2, Accs
# ✅ Loaded Seed 28, Alpha 2, Losses
# ✅ Loaded Seed 28, Alpha 2, Accs
# ✅ Loaded Seed 29, Alpha 2, Losses
# ✅ Loaded Seed 29, Alpha 2, Accs
# ✅ Loaded Seed 0, Alpha 5, Losses
# ✅ Loaded Seed 0, Alpha 5, Accs
# ✅ Loaded Seed 1, Alpha 5, Losses
# ✅ Loaded Seed 1, Alpha 5, Accs
# ✅ Loaded Seed 2, Alpha 5, Losses
# ✅ Loaded Seed 2, Alpha 5, Accs
# ✅ Loaded Seed 3, Alpha 5, Losses
# ✅ Loaded Seed 3, Alpha 5, Accs
# ✅ Loaded Seed 4, Alpha 5, Losses
# ✅ Loaded Seed 4, Alpha 5, Accs
# ✅ Loaded Seed 5, Alpha 5, Losses
# ✅ Loaded Seed 5, Alpha 5, Accs
# ✅ Loaded Seed 6, Alpha 5, Losses
# ✅ Loaded Seed 6, Alpha 5, Accs
# ✅ Loaded Seed 7, Alpha 5, Losses
# ✅ Loaded Seed 7, Alpha 5, Accs
# ✅ Loaded Seed 8, Alpha 5, Losses
# ✅ Loaded Seed 8, Alpha 5, Accs
# ✅ Loaded Seed 9, Alpha 5, Losses
# ✅ Loaded Seed 9, Alpha 5, Accs
# ✅ Loaded Seed 10, Alpha 5, Losses
# ✅ Loaded Seed 10, Alpha 5, Accs
# ✅ Loaded Seed 11, Alpha 5, Losses
# ✅ Loaded Seed 11, Alpha 5, Accs
# ✅ Loaded Seed 12, Alpha 5, Losses
# ✅ Loaded Seed 12, Alpha 5, Accs
# ✅ Loaded Seed 13, Alpha 5, Losses
# ✅ Loaded Seed 13, Alpha 5, Accs
# ✅ Loaded Seed 14, Alpha 5, Losses
# ✅ Loaded Seed 14, Alpha 5, Accs
# ✅ Loaded Seed 15, Alpha 5, Losses
# ✅ Loaded Seed 15, Alpha 5, Accs
# ✅ Loaded Seed 16, Alpha 5, Losses
# ✅ Loaded Seed 16, Alpha 5, Accs
# ✅ Loaded Seed 17, Alpha 5, Losses
# ✅ Loaded Seed 17, Alpha 5, Accs
# ✅ Loaded Seed 18, Alpha 5, Losses
# ✅ Loaded Seed 18, Alpha 5, Accs
# ✅ Loaded Seed 19, Alpha 5, Losses
# ✅ Loaded Seed 19, Alpha 5, Accs
# ✅ Loaded Seed 20, Alpha 5, Losses
# ✅ Loaded Seed 20, Alpha 5, Accs
# ✅ Loaded Seed 21, Alpha 5, Losses
# ✅ Loaded Seed 21, Alpha 5, Accs
# ✅ Loaded Seed 22, Alpha 5, Losses
# ✅ Loaded Seed 22, Alpha 5, Accs
# ✅ Loaded Seed 23, Alpha 5, Losses
# ✅ Loaded Seed 23, Alpha 5, Accs
# ✅ Loaded Seed 24, Alpha 5, Losses
# ✅ Loaded Seed 24, Alpha 5, Accs
# ✅ Loaded Seed 25, Alpha 5, Losses
# ✅ Loaded Seed 25, Alpha 5, Accs
# ✅ Loaded Seed 26, Alpha 5, Losses
# ✅ Loaded Seed 26, Alpha 5, Accs
# ✅ Loaded Seed 27, Alpha 5, Losses
# ✅ Loaded Seed 27, Alpha 5, Accs
# ✅ Loaded Seed 28, Alpha 5, Losses
# ✅ Loaded Seed 28, Alpha 5, Accs
# ✅ Loaded Seed 29, Alpha 5, Losses
# ✅ Loaded Seed 29, Alpha 5, Accs
# ✅ Loaded Seed 0, Alpha 10, Losses
# ✅ Loaded Seed 0, Alpha 10, Accs
# ✅ Loaded Seed 1, Alpha 10, Losses
# ✅ Loaded Seed 1, Alpha 10, Accs
# ✅ Loaded Seed 2, Alpha 10, Losses
# ✅ Loaded Seed 2, Alpha 10, Accs
# ✅ Loaded Seed 3, Alpha 10, Losses
# ✅ Loaded Seed 3, Alpha 10, Accs
# ✅ Loaded Seed 4, Alpha 10, Losses
# ✅ Loaded Seed 4, Alpha 10, Accs
# ✅ Loaded Seed 5, Alpha 10, Losses
# ✅ Loaded Seed 5, Alpha 10, Accs
# ✅ Loaded Seed 6, Alpha 10, Losses
# ✅ Loaded Seed 6, Alpha 10, Accs
# ✅ Loaded Seed 7, Alpha 10, Losses
# ✅ Loaded Seed 7, Alpha 10, Accs
# ✅ Loaded Seed 8, Alpha 10, Losses
# ✅ Loaded Seed 8, Alpha 10, Accs
# ✅ Loaded Seed 9, Alpha 10, Losses
# ✅ Loaded Seed 9, Alpha 10, Accs
# ✅ Loaded Seed 10, Alpha 10, Losses
# ✅ Loaded Seed 10, Alpha 10, Accs
# ✅ Loaded Seed 11, Alpha 10, Losses
# ✅ Loaded Seed 11, Alpha 10, Accs
# ✅ Loaded Seed 12, Alpha 10, Losses
# ✅ Loaded Seed 12, Alpha 10, Accs
# ✅ Loaded Seed 13, Alpha 10, Losses
# ✅ Loaded Seed 13, Alpha 10, Accs
# ✅ Loaded Seed 14, Alpha 10, Losses
# ✅ Loaded Seed 14, Alpha 10, Accs
# ✅ Loaded Seed 15, Alpha 10, Losses
# ✅ Loaded Seed 15, Alpha 10, Accs
# ✅ Loaded Seed 16, Alpha 10, Losses
# ✅ Loaded Seed 16, Alpha 10, Accs
# ✅ Loaded Seed 17, Alpha 10, Losses
# ✅ Loaded Seed 17, Alpha 10, Accs
# ✅ Loaded Seed 18, Alpha 10, Losses
# ✅ Loaded Seed 18, Alpha 10, Accs
# ✅ Loaded Seed 19, Alpha 10, Losses
# ✅ Loaded Seed 19, Alpha 10, Accs
# ✅ Loaded Seed 20, Alpha 10, Losses
# ✅ Loaded Seed 20, Alpha 10, Accs
# ✅ Loaded Seed 21, Alpha 10, Losses
# ✅ Loaded Seed 21, Alpha 10, Accs
# ✅ Loaded Seed 22, Alpha 10, Losses
# ✅ Loaded Seed 22, Alpha 10, Accs
# ✅ Loaded Seed 23, Alpha 10, Losses
# ✅ Loaded Seed 23, Alpha 10, Accs
# ✅ Loaded Seed 24, Alpha 10, Losses
# ✅ Loaded Seed 24, Alpha 10, Accs
# ✅ Loaded Seed 25, Alpha 10, Losses
# ✅ Loaded Seed 25, Alpha 10, Accs
# ✅ Loaded Seed 26, Alpha 10, Losses
# ✅ Loaded Seed 26, Alpha 10, Accs
# ✅ Loaded Seed 27, Alpha 10, Losses
# ✅ Loaded Seed 27, Alpha 10, Accs
# ✅ Loaded Seed 28, Alpha 10, Losses
# ✅ Loaded Seed 28, Alpha 10, Accs
# ✅ Loaded Seed 29, Alpha 10, Losses
# ✅ Loaded Seed 29, Alpha 10, Accs

# %%
seeds = list(range(30))
plot_metric_across_alphas(run_data, 'losses','train_aux' ,   alphas=[0.01,0.1,0.5,1.0,2,5,10],seeds=seeds) #plot_metric_across_alphas(run_data, 'losses', alphas=[0.1, 0.5, 1.0])
plot_metric_across_alphas(run_data, 'accs', 'train_aux', alphas=[0.01,0.1,0.5,1.0,2,5,10],seeds=seeds)
plot_metric_across_alphas(run_data, 'losses','valid_aux' , alphas=[0.01,0.1,0.5,1.0,2,5,10],seeds=seeds) #plot_metric_across_alphas(run_data, 'losses', alphas=[0.1, 0.5, 1.0])
plot_metric_across_alphas(run_data, 'accs', 'valid_aux' , alphas=[0.01,0.1,0.5,1.0,2,5,10],seeds=seeds) #
# Out:
# /tmp/ipykernel_3959783/2253447913.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(alphas))

# %%
import torch
import numpy as np
from pathlib import Path
seeds = list(range(50))
alphas = [0.125, 0.25, 0.5, 1., 2.]
n_samples=[10, 20, 50, 100, 200, 500, 1000]
base_path = Path("/nfs/gatsbystor/cdomine/cifar_testing/cifar/extentions")

run_data = {
    'losses': {a:{s: [] for s in n_samples} for a in alphas},
    'accs': {a: {s: [] for s in n_samples} for a in alphas},
    'models': {a: {s: [] for s in n_samples} for a in alphas},
    'l2_regs': {a: {s: [] for s in n_samples} for a in alphas}
}
for alpha in alphas:
    for seed in seeds:
        for n_sample in n_samples :
            folder_name = (
                f"random_seed={seed}--mode=finetuning--n_samples={ n_sample}--"
                f"finetune_scaling={alpha}"
            )
            
            dir_path = base_path / folder_name
            if dir_path.exists():
                print(f" {seed}, finetune {alpha}, Sample {n_sample}, Accs"),
                # Load and append data to the lists
                if (dir_path / "losses.npy").exists():
                    run_data['losses'][alpha][n_sample].append(np.load(dir_path / "losses.npy",allow_pickle=True))
                    print(f"✅ Loaded Seed {seed}, Alpha {alpha}, Sample {n_sample}, Losses")
                if (dir_path / "l2_regs.npy").exists():
                    run_data['l2_regs'][alpha][n_sample].append(np.load(dir_path / "l2_regs.npy",allow_pickle=True))
                    print(f"✅ Loaded Seed {seed}, Alpha {alpha}, Sample {n_sample}, l2_regs")
                if (dir_path / "accs.npy").exists():
                    run_data['accs'][alpha][n_sample].append(np.load(dir_path / "accs.npy",allow_pickle=True))
                    print(f"✅ Loaded Seed {seed}, Alpha {alpha}, Sample {n_sample}, Accs"),
            else:
                print(f"Missing directory: {folder_name}")
# Out:
#  0, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 0, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 0, Alpha 0.125, Sample 10, Accs
#  0, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 0, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 0, Alpha 0.125, Sample 20, Accs
#  0, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 0, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 0, Alpha 0.125, Sample 50, Accs
#  0, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 0, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 0, Alpha 0.125, Sample 100, Accs
#  0, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 0, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 0, Alpha 0.125, Sample 200, Accs
#  0, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 0, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 0, Alpha 0.125, Sample 500, Accs
#  0, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 0, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 0, Alpha 0.125, Sample 1000, Accs
#  1, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 1, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 1, Alpha 0.125, Sample 10, Accs
#  1, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 1, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 1, Alpha 0.125, Sample 20, Accs
#  1, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 1, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 1, Alpha 0.125, Sample 50, Accs
#  1, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 1, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 1, Alpha 0.125, Sample 100, Accs
#  1, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 1, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 1, Alpha 0.125, Sample 200, Accs
#  1, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 1, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 1, Alpha 0.125, Sample 500, Accs
#  1, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 1, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 1, Alpha 0.125, Sample 1000, Accs
#  2, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 2, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 2, Alpha 0.125, Sample 10, Accs
#  2, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 2, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 2, Alpha 0.125, Sample 20, Accs
#  2, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 2, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 2, Alpha 0.125, Sample 50, Accs
#  2, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 2, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 2, Alpha 0.125, Sample 100, Accs
#  2, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 2, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 2, Alpha 0.125, Sample 200, Accs
#  2, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 2, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 2, Alpha 0.125, Sample 500, Accs
#  2, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 2, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 2, Alpha 0.125, Sample 1000, Accs
#  3, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 3, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 3, Alpha 0.125, Sample 10, Accs
#  3, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 3, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 3, Alpha 0.125, Sample 20, Accs
#  3, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 3, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 3, Alpha 0.125, Sample 50, Accs
#  3, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 3, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 3, Alpha 0.125, Sample 100, Accs
#  3, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 3, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 3, Alpha 0.125, Sample 200, Accs
#  3, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 3, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 3, Alpha 0.125, Sample 500, Accs
#  3, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 3, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 3, Alpha 0.125, Sample 1000, Accs
#  4, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 4, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 4, Alpha 0.125, Sample 10, Accs
#  4, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 4, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 4, Alpha 0.125, Sample 20, Accs
#  4, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 4, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 4, Alpha 0.125, Sample 50, Accs
#  4, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 4, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 4, Alpha 0.125, Sample 100, Accs
#  4, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 4, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 4, Alpha 0.125, Sample 200, Accs
#  4, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 4, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 4, Alpha 0.125, Sample 500, Accs
#  4, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 4, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 4, Alpha 0.125, Sample 1000, Accs
#  5, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 5, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 5, Alpha 0.125, Sample 10, Accs
#  5, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 5, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 5, Alpha 0.125, Sample 20, Accs
#  5, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 5, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 5, Alpha 0.125, Sample 50, Accs
#  5, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 5, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 5, Alpha 0.125, Sample 100, Accs
#  5, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 5, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 5, Alpha 0.125, Sample 200, Accs
#  5, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 5, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 5, Alpha 0.125, Sample 500, Accs
#  5, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 5, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 5, Alpha 0.125, Sample 1000, Accs
#  6, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 6, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 6, Alpha 0.125, Sample 10, Accs
#  6, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 6, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 6, Alpha 0.125, Sample 20, Accs
#  6, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 6, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 6, Alpha 0.125, Sample 50, Accs
#  6, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 6, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 6, Alpha 0.125, Sample 100, Accs
#  6, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 6, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 6, Alpha 0.125, Sample 200, Accs
#  6, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 6, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 6, Alpha 0.125, Sample 500, Accs
#  6, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 6, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 6, Alpha 0.125, Sample 1000, Accs
#  7, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 7, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 7, Alpha 0.125, Sample 10, Accs
#  7, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 7, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 7, Alpha 0.125, Sample 20, Accs
#  7, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 7, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 7, Alpha 0.125, Sample 50, Accs
#  7, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 7, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 7, Alpha 0.125, Sample 100, Accs
#  7, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 7, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 7, Alpha 0.125, Sample 200, Accs
#  7, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 7, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 7, Alpha 0.125, Sample 500, Accs
#  7, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 7, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 7, Alpha 0.125, Sample 1000, Accs
#  8, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 8, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 8, Alpha 0.125, Sample 10, Accs
#  8, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 8, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 8, Alpha 0.125, Sample 20, Accs
#  8, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 8, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 8, Alpha 0.125, Sample 50, Accs
#  8, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 8, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 8, Alpha 0.125, Sample 100, Accs
#  8, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 8, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 8, Alpha 0.125, Sample 200, Accs
#  8, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 8, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 8, Alpha 0.125, Sample 500, Accs
#  8, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 8, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 8, Alpha 0.125, Sample 1000, Accs
#  9, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 9, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 9, Alpha 0.125, Sample 10, Accs
#  9, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 9, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 9, Alpha 0.125, Sample 20, Accs
#  9, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 9, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 9, Alpha 0.125, Sample 50, Accs
#  9, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 9, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 9, Alpha 0.125, Sample 100, Accs
#  9, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 9, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 9, Alpha 0.125, Sample 200, Accs
#  9, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 9, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 9, Alpha 0.125, Sample 500, Accs
#  9, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 9, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 9, Alpha 0.125, Sample 1000, Accs
#  10, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 10, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 10, Alpha 0.125, Sample 10, Accs
#  10, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 10, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 10, Alpha 0.125, Sample 20, Accs
#  10, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 10, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 10, Alpha 0.125, Sample 50, Accs
#  10, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 10, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 10, Alpha 0.125, Sample 100, Accs
#  10, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 10, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 10, Alpha 0.125, Sample 200, Accs
#  10, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 10, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 10, Alpha 0.125, Sample 500, Accs
#  10, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 10, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 10, Alpha 0.125, Sample 1000, Accs
#  11, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 11, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 11, Alpha 0.125, Sample 10, Accs
#  11, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 11, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 11, Alpha 0.125, Sample 20, Accs
#  11, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 11, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 11, Alpha 0.125, Sample 50, Accs
#  11, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 11, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 11, Alpha 0.125, Sample 100, Accs
#  11, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 11, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 11, Alpha 0.125, Sample 200, Accs
#  11, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 11, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 11, Alpha 0.125, Sample 500, Accs
#  11, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 11, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 11, Alpha 0.125, Sample 1000, Accs
#  12, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 12, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 12, Alpha 0.125, Sample 10, Accs
#  12, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 12, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 12, Alpha 0.125, Sample 20, Accs
#  12, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 12, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 12, Alpha 0.125, Sample 50, Accs
#  12, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 12, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 12, Alpha 0.125, Sample 100, Accs
#  12, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 12, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 12, Alpha 0.125, Sample 200, Accs
#  12, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 12, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 12, Alpha 0.125, Sample 500, Accs
#  12, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 12, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 12, Alpha 0.125, Sample 1000, Accs
#  13, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 13, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 13, Alpha 0.125, Sample 10, Accs
#  13, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 13, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 13, Alpha 0.125, Sample 20, Accs
#  13, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 13, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 13, Alpha 0.125, Sample 50, Accs
#  13, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 13, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 13, Alpha 0.125, Sample 100, Accs
#  13, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 13, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 13, Alpha 0.125, Sample 200, Accs
#  13, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 13, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 13, Alpha 0.125, Sample 500, Accs
#  13, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 13, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 13, Alpha 0.125, Sample 1000, Accs
#  14, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 14, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 14, Alpha 0.125, Sample 10, Accs
#  14, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 14, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 14, Alpha 0.125, Sample 20, Accs
#  14, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 14, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 14, Alpha 0.125, Sample 50, Accs
#  14, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 14, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 14, Alpha 0.125, Sample 100, Accs
#  14, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 14, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 14, Alpha 0.125, Sample 200, Accs
#  14, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 14, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 14, Alpha 0.125, Sample 500, Accs
#  14, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 14, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 14, Alpha 0.125, Sample 1000, Accs
#  15, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 15, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 15, Alpha 0.125, Sample 10, Accs
#  15, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 15, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 15, Alpha 0.125, Sample 20, Accs
#  15, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 15, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 15, Alpha 0.125, Sample 50, Accs
#  15, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 15, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 15, Alpha 0.125, Sample 100, Accs
#  15, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 15, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 15, Alpha 0.125, Sample 200, Accs
#  15, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 15, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 15, Alpha 0.125, Sample 500, Accs
#  15, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 15, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 15, Alpha 0.125, Sample 1000, Accs
#  16, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 16, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 16, Alpha 0.125, Sample 10, Accs
#  16, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 16, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 16, Alpha 0.125, Sample 20, Accs
#  16, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 16, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 16, Alpha 0.125, Sample 50, Accs
#  16, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 16, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 16, Alpha 0.125, Sample 100, Accs
#  16, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 16, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 16, Alpha 0.125, Sample 200, Accs
#  16, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 16, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 16, Alpha 0.125, Sample 500, Accs
#  16, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 16, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 16, Alpha 0.125, Sample 1000, Accs
#  17, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 17, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 17, Alpha 0.125, Sample 10, Accs
#  17, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 17, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 17, Alpha 0.125, Sample 20, Accs
#  17, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 17, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 17, Alpha 0.125, Sample 50, Accs
#  17, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 17, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 17, Alpha 0.125, Sample 100, Accs
#  17, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 17, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 17, Alpha 0.125, Sample 200, Accs
#  17, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 17, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 17, Alpha 0.125, Sample 500, Accs
#  17, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 17, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 17, Alpha 0.125, Sample 1000, Accs
#  18, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 18, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 18, Alpha 0.125, Sample 10, Accs
#  18, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 18, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 18, Alpha 0.125, Sample 20, Accs
#  18, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 18, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 18, Alpha 0.125, Sample 50, Accs
#  18, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 18, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 18, Alpha 0.125, Sample 100, Accs
#  18, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 18, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 18, Alpha 0.125, Sample 200, Accs
#  18, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 18, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 18, Alpha 0.125, Sample 500, Accs
#  18, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 18, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 18, Alpha 0.125, Sample 1000, Accs
#  19, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 19, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 19, Alpha 0.125, Sample 10, Accs
#  19, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 19, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 19, Alpha 0.125, Sample 20, Accs
#  19, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 19, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 19, Alpha 0.125, Sample 50, Accs
#  19, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 19, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 19, Alpha 0.125, Sample 100, Accs
#  19, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 19, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 19, Alpha 0.125, Sample 200, Accs
#  19, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 19, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 19, Alpha 0.125, Sample 500, Accs
#  19, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 19, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 19, Alpha 0.125, Sample 1000, Accs
#  20, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 20, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 20, Alpha 0.125, Sample 10, Accs
#  20, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 20, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 20, Alpha 0.125, Sample 20, Accs
#  20, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 20, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 20, Alpha 0.125, Sample 50, Accs
#  20, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 20, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 20, Alpha 0.125, Sample 100, Accs
#  20, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 20, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 20, Alpha 0.125, Sample 200, Accs
#  20, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 20, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 20, Alpha 0.125, Sample 500, Accs
#  20, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 20, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 20, Alpha 0.125, Sample 1000, Accs
#  21, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 21, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 21, Alpha 0.125, Sample 10, Accs
#  21, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 21, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 21, Alpha 0.125, Sample 20, Accs
#  21, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 21, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 21, Alpha 0.125, Sample 50, Accs
#  21, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 21, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 21, Alpha 0.125, Sample 100, Accs
#  21, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 21, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 21, Alpha 0.125, Sample 200, Accs
#  21, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 21, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 21, Alpha 0.125, Sample 500, Accs
#  21, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 21, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 21, Alpha 0.125, Sample 1000, Accs
#  22, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 22, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 22, Alpha 0.125, Sample 10, Accs
#  22, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 22, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 22, Alpha 0.125, Sample 20, Accs
#  22, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 22, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 22, Alpha 0.125, Sample 50, Accs
#  22, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 22, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 22, Alpha 0.125, Sample 100, Accs
#  22, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 22, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 22, Alpha 0.125, Sample 200, Accs
#  22, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 22, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 22, Alpha 0.125, Sample 500, Accs
#  22, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 22, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 22, Alpha 0.125, Sample 1000, Accs
#  23, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 23, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 23, Alpha 0.125, Sample 10, Accs
#  23, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 23, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 23, Alpha 0.125, Sample 20, Accs
#  23, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 23, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 23, Alpha 0.125, Sample 50, Accs
#  23, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 23, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 23, Alpha 0.125, Sample 100, Accs
#  23, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 23, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 23, Alpha 0.125, Sample 200, Accs
#  23, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 23, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 23, Alpha 0.125, Sample 500, Accs
#  23, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 23, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 23, Alpha 0.125, Sample 1000, Accs
#  24, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 24, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 24, Alpha 0.125, Sample 10, Accs
#  24, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 24, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 24, Alpha 0.125, Sample 20, Accs
#  24, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 24, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 24, Alpha 0.125, Sample 50, Accs
#  24, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 24, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 24, Alpha 0.125, Sample 100, Accs
#  24, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 24, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 24, Alpha 0.125, Sample 200, Accs
#  24, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 24, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 24, Alpha 0.125, Sample 500, Accs
#  24, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 24, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 24, Alpha 0.125, Sample 1000, Accs
#  25, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 25, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 25, Alpha 0.125, Sample 10, Accs
#  25, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 25, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 25, Alpha 0.125, Sample 20, Accs
#  25, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 25, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 25, Alpha 0.125, Sample 50, Accs
#  25, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 25, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 25, Alpha 0.125, Sample 100, Accs
#  25, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 25, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 25, Alpha 0.125, Sample 200, Accs
#  25, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 25, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 25, Alpha 0.125, Sample 500, Accs
#  25, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 25, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 25, Alpha 0.125, Sample 1000, Accs
#  26, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 26, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 26, Alpha 0.125, Sample 10, Accs
#  26, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 26, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 26, Alpha 0.125, Sample 20, Accs
#  26, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 26, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 26, Alpha 0.125, Sample 50, Accs
#  26, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 26, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 26, Alpha 0.125, Sample 100, Accs
#  26, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 26, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 26, Alpha 0.125, Sample 200, Accs
#  26, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 26, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 26, Alpha 0.125, Sample 500, Accs
#  26, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 26, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 26, Alpha 0.125, Sample 1000, Accs
#  27, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 27, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 27, Alpha 0.125, Sample 10, Accs
#  27, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 27, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 27, Alpha 0.125, Sample 20, Accs
#  27, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 27, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 27, Alpha 0.125, Sample 50, Accs
#  27, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 27, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 27, Alpha 0.125, Sample 100, Accs
#  27, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 27, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 27, Alpha 0.125, Sample 200, Accs
#  27, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 27, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 27, Alpha 0.125, Sample 500, Accs
#  27, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 27, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 27, Alpha 0.125, Sample 1000, Accs
#  28, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 28, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 28, Alpha 0.125, Sample 10, Accs
#  28, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 28, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 28, Alpha 0.125, Sample 20, Accs
#  28, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 28, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 28, Alpha 0.125, Sample 50, Accs
#  28, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 28, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 28, Alpha 0.125, Sample 100, Accs
#  28, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 28, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 28, Alpha 0.125, Sample 200, Accs
#  28, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 28, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 28, Alpha 0.125, Sample 500, Accs
#  28, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 28, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 28, Alpha 0.125, Sample 1000, Accs
#  29, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 29, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 29, Alpha 0.125, Sample 10, Accs
#  29, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 29, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 29, Alpha 0.125, Sample 20, Accs
#  29, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 29, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 29, Alpha 0.125, Sample 50, Accs
#  29, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 29, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 29, Alpha 0.125, Sample 100, Accs
#  29, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 29, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 29, Alpha 0.125, Sample 200, Accs
#  29, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 29, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 29, Alpha 0.125, Sample 500, Accs
#  29, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 29, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 29, Alpha 0.125, Sample 1000, Accs
#  30, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 30, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 30, Alpha 0.125, Sample 10, Accs
#  30, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 30, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 30, Alpha 0.125, Sample 20, Accs
#  30, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 30, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 30, Alpha 0.125, Sample 50, Accs
#  30, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 30, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 30, Alpha 0.125, Sample 100, Accs
#  30, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 30, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 30, Alpha 0.125, Sample 200, Accs
#  30, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 30, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 30, Alpha 0.125, Sample 500, Accs
#  30, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 30, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 30, Alpha 0.125, Sample 1000, Accs
#  31, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 31, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 31, Alpha 0.125, Sample 10, Accs
#  31, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 31, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 31, Alpha 0.125, Sample 20, Accs
#  31, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 31, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 31, Alpha 0.125, Sample 50, Accs
#  31, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 31, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 31, Alpha 0.125, Sample 100, Accs
#  31, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 31, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 31, Alpha 0.125, Sample 200, Accs
#  31, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 31, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 31, Alpha 0.125, Sample 500, Accs
#  31, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 31, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 31, Alpha 0.125, Sample 1000, Accs
#  32, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 32, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 32, Alpha 0.125, Sample 10, Accs
#  32, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 32, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 32, Alpha 0.125, Sample 20, Accs
#  32, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 32, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 32, Alpha 0.125, Sample 50, Accs
#  32, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 32, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 32, Alpha 0.125, Sample 100, Accs
#  32, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 32, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 32, Alpha 0.125, Sample 200, Accs
#  32, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 32, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 32, Alpha 0.125, Sample 500, Accs
#  32, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 32, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 32, Alpha 0.125, Sample 1000, Accs
#  33, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 33, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 33, Alpha 0.125, Sample 10, Accs
#  33, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 33, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 33, Alpha 0.125, Sample 20, Accs
#  33, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 33, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 33, Alpha 0.125, Sample 50, Accs
#  33, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 33, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 33, Alpha 0.125, Sample 100, Accs
#  33, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 33, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 33, Alpha 0.125, Sample 200, Accs
#  33, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 33, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 33, Alpha 0.125, Sample 500, Accs
#  33, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 33, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 33, Alpha 0.125, Sample 1000, Accs
#  34, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 34, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 34, Alpha 0.125, Sample 10, Accs
#  34, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 34, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 34, Alpha 0.125, Sample 20, Accs
#  34, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 34, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 34, Alpha 0.125, Sample 50, Accs
#  34, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 34, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 34, Alpha 0.125, Sample 100, Accs
#  34, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 34, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 34, Alpha 0.125, Sample 200, Accs
#  34, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 34, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 34, Alpha 0.125, Sample 500, Accs
#  34, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 34, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 34, Alpha 0.125, Sample 1000, Accs
#  35, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 35, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 35, Alpha 0.125, Sample 10, Accs
#  35, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 35, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 35, Alpha 0.125, Sample 20, Accs
#  35, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 35, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 35, Alpha 0.125, Sample 50, Accs
#  35, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 35, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 35, Alpha 0.125, Sample 100, Accs
#  35, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 35, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 35, Alpha 0.125, Sample 200, Accs
#  35, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 35, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 35, Alpha 0.125, Sample 500, Accs
#  35, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 35, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 35, Alpha 0.125, Sample 1000, Accs
#  36, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 36, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 36, Alpha 0.125, Sample 10, Accs
#  36, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 36, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 36, Alpha 0.125, Sample 20, Accs
#  36, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 36, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 36, Alpha 0.125, Sample 50, Accs
#  36, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 36, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 36, Alpha 0.125, Sample 100, Accs
#  36, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 36, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 36, Alpha 0.125, Sample 200, Accs
#  36, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 36, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 36, Alpha 0.125, Sample 500, Accs
#  36, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 36, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 36, Alpha 0.125, Sample 1000, Accs
#  37, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 37, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 37, Alpha 0.125, Sample 10, Accs
#  37, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 37, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 37, Alpha 0.125, Sample 20, Accs
#  37, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 37, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 37, Alpha 0.125, Sample 50, Accs
#  37, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 37, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 37, Alpha 0.125, Sample 100, Accs
#  37, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 37, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 37, Alpha 0.125, Sample 200, Accs
#  37, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 37, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 37, Alpha 0.125, Sample 500, Accs
#  37, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 37, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 37, Alpha 0.125, Sample 1000, Accs
#  38, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 38, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 38, Alpha 0.125, Sample 10, Accs
#  38, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 38, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 38, Alpha 0.125, Sample 20, Accs
#  38, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 38, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 38, Alpha 0.125, Sample 50, Accs
#  38, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 38, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 38, Alpha 0.125, Sample 100, Accs
#  38, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 38, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 38, Alpha 0.125, Sample 200, Accs
#  38, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 38, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 38, Alpha 0.125, Sample 500, Accs
#  38, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 38, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 38, Alpha 0.125, Sample 1000, Accs
#  39, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 39, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 39, Alpha 0.125, Sample 10, Accs
#  39, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 39, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 39, Alpha 0.125, Sample 20, Accs
#  39, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 39, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 39, Alpha 0.125, Sample 50, Accs
#  39, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 39, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 39, Alpha 0.125, Sample 100, Accs
#  39, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 39, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 39, Alpha 0.125, Sample 200, Accs
#  39, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 39, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 39, Alpha 0.125, Sample 500, Accs
#  39, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 39, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 39, Alpha 0.125, Sample 1000, Accs
#  40, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 40, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 40, Alpha 0.125, Sample 10, Accs
#  40, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 40, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 40, Alpha 0.125, Sample 20, Accs
#  40, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 40, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 40, Alpha 0.125, Sample 50, Accs
#  40, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 40, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 40, Alpha 0.125, Sample 100, Accs
#  40, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 40, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 40, Alpha 0.125, Sample 200, Accs
#  40, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 40, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 40, Alpha 0.125, Sample 500, Accs
#  40, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 40, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 40, Alpha 0.125, Sample 1000, Accs
#  41, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 41, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 41, Alpha 0.125, Sample 10, Accs
#  41, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 41, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 41, Alpha 0.125, Sample 20, Accs
#  41, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 41, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 41, Alpha 0.125, Sample 50, Accs
#  41, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 41, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 41, Alpha 0.125, Sample 100, Accs
#  41, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 41, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 41, Alpha 0.125, Sample 200, Accs
#  41, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 41, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 41, Alpha 0.125, Sample 500, Accs
#  41, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 41, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 41, Alpha 0.125, Sample 1000, Accs
#  42, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 42, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 42, Alpha 0.125, Sample 10, Accs
#  42, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 42, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 42, Alpha 0.125, Sample 20, Accs
#  42, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 42, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 42, Alpha 0.125, Sample 50, Accs
#  42, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 42, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 42, Alpha 0.125, Sample 100, Accs
#  42, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 42, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 42, Alpha 0.125, Sample 200, Accs
#  42, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 42, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 42, Alpha 0.125, Sample 500, Accs
#  42, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 42, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 42, Alpha 0.125, Sample 1000, Accs
#  43, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 43, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 43, Alpha 0.125, Sample 10, Accs
#  43, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 43, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 43, Alpha 0.125, Sample 20, Accs
#  43, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 43, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 43, Alpha 0.125, Sample 50, Accs
#  43, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 43, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 43, Alpha 0.125, Sample 100, Accs
#  43, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 43, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 43, Alpha 0.125, Sample 200, Accs
#  43, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 43, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 43, Alpha 0.125, Sample 500, Accs
#  43, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 43, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 43, Alpha 0.125, Sample 1000, Accs
#  44, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 44, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 44, Alpha 0.125, Sample 10, Accs
#  44, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 44, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 44, Alpha 0.125, Sample 20, Accs
#  44, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 44, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 44, Alpha 0.125, Sample 50, Accs
#  44, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 44, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 44, Alpha 0.125, Sample 100, Accs
#  44, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 44, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 44, Alpha 0.125, Sample 200, Accs
#  44, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 44, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 44, Alpha 0.125, Sample 500, Accs
#  44, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 44, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 44, Alpha 0.125, Sample 1000, Accs
#  45, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 45, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 45, Alpha 0.125, Sample 10, Accs
#  45, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 45, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 45, Alpha 0.125, Sample 20, Accs
#  45, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 45, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 45, Alpha 0.125, Sample 50, Accs
#  45, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 45, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 45, Alpha 0.125, Sample 100, Accs
#  45, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 45, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 45, Alpha 0.125, Sample 200, Accs
#  45, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 45, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 45, Alpha 0.125, Sample 500, Accs
#  45, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 45, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 45, Alpha 0.125, Sample 1000, Accs
#  46, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 46, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 46, Alpha 0.125, Sample 10, Accs
#  46, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 46, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 46, Alpha 0.125, Sample 20, Accs
#  46, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 46, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 46, Alpha 0.125, Sample 50, Accs
#  46, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 46, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 46, Alpha 0.125, Sample 100, Accs
#  46, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 46, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 46, Alpha 0.125, Sample 200, Accs
#  46, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 46, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 46, Alpha 0.125, Sample 500, Accs
#  46, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 46, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 46, Alpha 0.125, Sample 1000, Accs
#  47, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 47, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 47, Alpha 0.125, Sample 10, Accs
#  47, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 47, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 47, Alpha 0.125, Sample 20, Accs
#  47, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 47, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 47, Alpha 0.125, Sample 50, Accs
#  47, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 47, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 47, Alpha 0.125, Sample 100, Accs
#  47, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 47, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 47, Alpha 0.125, Sample 200, Accs
#  47, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 47, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 47, Alpha 0.125, Sample 500, Accs
#  47, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 47, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 47, Alpha 0.125, Sample 1000, Accs
#  48, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 48, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 48, Alpha 0.125, Sample 10, Accs
#  48, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 48, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 48, Alpha 0.125, Sample 20, Accs
#  48, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 48, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 48, Alpha 0.125, Sample 50, Accs
#  48, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 48, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 48, Alpha 0.125, Sample 100, Accs
#  48, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 48, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 48, Alpha 0.125, Sample 200, Accs
#  48, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 48, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 48, Alpha 0.125, Sample 500, Accs
#  48, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 48, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 48, Alpha 0.125, Sample 1000, Accs
#  49, finetune 0.125, Sample 10, Accs
# ✅ Loaded Seed 49, Alpha 0.125, Sample 10, Losses
# ✅ Loaded Seed 49, Alpha 0.125, Sample 10, Accs
#  49, finetune 0.125, Sample 20, Accs
# ✅ Loaded Seed 49, Alpha 0.125, Sample 20, Losses
# ✅ Loaded Seed 49, Alpha 0.125, Sample 20, Accs
#  49, finetune 0.125, Sample 50, Accs
# ✅ Loaded Seed 49, Alpha 0.125, Sample 50, Losses
# ✅ Loaded Seed 49, Alpha 0.125, Sample 50, Accs
#  49, finetune 0.125, Sample 100, Accs
# ✅ Loaded Seed 49, Alpha 0.125, Sample 100, Losses
# ✅ Loaded Seed 49, Alpha 0.125, Sample 100, Accs
#  49, finetune 0.125, Sample 200, Accs
# ✅ Loaded Seed 49, Alpha 0.125, Sample 200, Losses
# ✅ Loaded Seed 49, Alpha 0.125, Sample 200, Accs
#  49, finetune 0.125, Sample 500, Accs
# ✅ Loaded Seed 49, Alpha 0.125, Sample 500, Losses
# ✅ Loaded Seed 49, Alpha 0.125, Sample 500, Accs
#  49, finetune 0.125, Sample 1000, Accs
# ✅ Loaded Seed 49, Alpha 0.125, Sample 1000, Losses
# ✅ Loaded Seed 49, Alpha 0.125, Sample 1000, Accs
#  0, finetune 0.25, Sample 10, Accs
# ✅ Loaded Seed 0, Alpha 0.25, Sample 10, Losses
# ✅ Loaded Seed 0, Alpha 0.25, Sample 10, Accs
#  0, finetune 0.25, Sample 20, Accs
# ✅ Loaded Seed 0, Alpha 0.25, Sample 20, Losses
# ✅ Loaded Seed 0, Alpha 0.25, Sample 20, Accs
#  0, finetune 0.25, Sample 50, Accs
# ✅ Loaded Seed 0, Alpha 0.25, Sample 50, Losses
# ✅ Loaded Seed 0, Alpha 0.25, Sample 50, Accs
#  0, finetune 0.25, Sample 100, Accs
# ✅ Loaded Seed 0, Alpha 0.25, Sample 100, Losses
# ✅ Loaded Seed 0, Alpha 0.25, Sample 100, Accs
#  0, finetune 0.25, Sample 200, Accs
# ✅ Loaded Seed 0, Alpha 0.25, Sample 200, Losses
# ✅ Loaded Seed 0, Alpha 0.25, Sample 200, Accs
#  0, finetune 0.25, Sample 500, Accs
# ✅ Loaded Seed 0, Alpha 0.25, Sample 500, Losses
# ✅ Loaded Seed 0, Alpha 0.25, Sample 500, Accs
#  0, finetune 0.25, Sample 1000, Accs
# ✅ Loaded Seed 0, Alpha 0.25, Sample 1000, Losses
# ✅ Loaded Seed 0, Alpha 0.25, Sample 1000, Accs
# ...
# ✅ Loaded Seed 32, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 32, Alpha 2.0, Sample 50, Accs
#  32, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 32, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 32, Alpha 2.0, Sample 100, Accs
#  32, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 32, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 32, Alpha 2.0, Sample 200, Accs
#  32, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 32, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 32, Alpha 2.0, Sample 500, Accs
#  32, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 32, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 32, Alpha 2.0, Sample 1000, Accs
#  33, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 33, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 33, Alpha 2.0, Sample 10, Accs
#  33, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 33, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 33, Alpha 2.0, Sample 20, Accs
#  33, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 33, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 33, Alpha 2.0, Sample 50, Accs
#  33, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 33, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 33, Alpha 2.0, Sample 100, Accs
#  33, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 33, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 33, Alpha 2.0, Sample 200, Accs
#  33, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 33, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 33, Alpha 2.0, Sample 500, Accs
#  33, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 33, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 33, Alpha 2.0, Sample 1000, Accs
#  34, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 34, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 34, Alpha 2.0, Sample 10, Accs
#  34, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 34, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 34, Alpha 2.0, Sample 20, Accs
#  34, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 34, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 34, Alpha 2.0, Sample 50, Accs
#  34, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 34, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 34, Alpha 2.0, Sample 100, Accs
#  34, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 34, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 34, Alpha 2.0, Sample 200, Accs
#  34, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 34, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 34, Alpha 2.0, Sample 500, Accs
#  34, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 34, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 34, Alpha 2.0, Sample 1000, Accs
#  35, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 35, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 35, Alpha 2.0, Sample 10, Accs
#  35, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 35, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 35, Alpha 2.0, Sample 20, Accs
#  35, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 35, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 35, Alpha 2.0, Sample 50, Accs
#  35, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 35, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 35, Alpha 2.0, Sample 100, Accs
#  35, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 35, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 35, Alpha 2.0, Sample 200, Accs
#  35, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 35, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 35, Alpha 2.0, Sample 500, Accs
#  35, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 35, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 35, Alpha 2.0, Sample 1000, Accs
#  36, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 36, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 36, Alpha 2.0, Sample 10, Accs
#  36, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 36, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 36, Alpha 2.0, Sample 20, Accs
#  36, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 36, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 36, Alpha 2.0, Sample 50, Accs
#  36, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 36, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 36, Alpha 2.0, Sample 100, Accs
#  36, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 36, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 36, Alpha 2.0, Sample 200, Accs
#  36, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 36, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 36, Alpha 2.0, Sample 500, Accs
#  36, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 36, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 36, Alpha 2.0, Sample 1000, Accs
#  37, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 37, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 37, Alpha 2.0, Sample 10, Accs
#  37, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 37, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 37, Alpha 2.0, Sample 20, Accs
#  37, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 37, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 37, Alpha 2.0, Sample 50, Accs
#  37, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 37, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 37, Alpha 2.0, Sample 100, Accs
#  37, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 37, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 37, Alpha 2.0, Sample 200, Accs
#  37, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 37, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 37, Alpha 2.0, Sample 500, Accs
#  37, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 37, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 37, Alpha 2.0, Sample 1000, Accs
#  38, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 38, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 38, Alpha 2.0, Sample 10, Accs
#  38, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 38, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 38, Alpha 2.0, Sample 20, Accs
#  38, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 38, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 38, Alpha 2.0, Sample 50, Accs
#  38, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 38, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 38, Alpha 2.0, Sample 100, Accs
#  38, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 38, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 38, Alpha 2.0, Sample 200, Accs
#  38, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 38, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 38, Alpha 2.0, Sample 500, Accs
#  38, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 38, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 38, Alpha 2.0, Sample 1000, Accs
#  39, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 39, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 39, Alpha 2.0, Sample 10, Accs
#  39, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 39, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 39, Alpha 2.0, Sample 20, Accs
#  39, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 39, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 39, Alpha 2.0, Sample 50, Accs
#  39, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 39, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 39, Alpha 2.0, Sample 100, Accs
#  39, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 39, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 39, Alpha 2.0, Sample 200, Accs
#  39, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 39, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 39, Alpha 2.0, Sample 500, Accs
#  39, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 39, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 39, Alpha 2.0, Sample 1000, Accs
#  40, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 40, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 40, Alpha 2.0, Sample 10, Accs
#  40, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 40, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 40, Alpha 2.0, Sample 20, Accs
#  40, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 40, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 40, Alpha 2.0, Sample 50, Accs
#  40, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 40, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 40, Alpha 2.0, Sample 100, Accs
#  40, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 40, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 40, Alpha 2.0, Sample 200, Accs
#  40, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 40, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 40, Alpha 2.0, Sample 500, Accs
#  40, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 40, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 40, Alpha 2.0, Sample 1000, Accs
#  41, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 41, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 41, Alpha 2.0, Sample 10, Accs
#  41, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 41, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 41, Alpha 2.0, Sample 20, Accs
#  41, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 41, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 41, Alpha 2.0, Sample 50, Accs
#  41, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 41, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 41, Alpha 2.0, Sample 100, Accs
#  41, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 41, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 41, Alpha 2.0, Sample 200, Accs
#  41, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 41, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 41, Alpha 2.0, Sample 500, Accs
#  41, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 41, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 41, Alpha 2.0, Sample 1000, Accs
#  42, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 42, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 42, Alpha 2.0, Sample 10, Accs
#  42, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 42, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 42, Alpha 2.0, Sample 20, Accs
#  42, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 42, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 42, Alpha 2.0, Sample 50, Accs
#  42, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 42, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 42, Alpha 2.0, Sample 100, Accs
#  42, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 42, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 42, Alpha 2.0, Sample 200, Accs
#  42, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 42, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 42, Alpha 2.0, Sample 500, Accs
#  42, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 42, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 42, Alpha 2.0, Sample 1000, Accs
#  43, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 43, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 43, Alpha 2.0, Sample 10, Accs
#  43, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 43, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 43, Alpha 2.0, Sample 20, Accs
#  43, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 43, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 43, Alpha 2.0, Sample 50, Accs
#  43, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 43, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 43, Alpha 2.0, Sample 100, Accs
#  43, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 43, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 43, Alpha 2.0, Sample 200, Accs
#  43, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 43, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 43, Alpha 2.0, Sample 500, Accs
#  43, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 43, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 43, Alpha 2.0, Sample 1000, Accs
#  44, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 44, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 44, Alpha 2.0, Sample 10, Accs
#  44, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 44, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 44, Alpha 2.0, Sample 20, Accs
#  44, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 44, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 44, Alpha 2.0, Sample 50, Accs
#  44, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 44, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 44, Alpha 2.0, Sample 100, Accs
#  44, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 44, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 44, Alpha 2.0, Sample 200, Accs
#  44, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 44, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 44, Alpha 2.0, Sample 500, Accs
#  44, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 44, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 44, Alpha 2.0, Sample 1000, Accs
#  45, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 45, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 45, Alpha 2.0, Sample 10, Accs
#  45, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 45, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 45, Alpha 2.0, Sample 20, Accs
#  45, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 45, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 45, Alpha 2.0, Sample 50, Accs
#  45, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 45, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 45, Alpha 2.0, Sample 100, Accs
#  45, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 45, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 45, Alpha 2.0, Sample 200, Accs
#  45, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 45, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 45, Alpha 2.0, Sample 500, Accs
#  45, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 45, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 45, Alpha 2.0, Sample 1000, Accs
#  46, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 46, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 46, Alpha 2.0, Sample 10, Accs
#  46, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 46, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 46, Alpha 2.0, Sample 20, Accs
#  46, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 46, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 46, Alpha 2.0, Sample 50, Accs
#  46, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 46, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 46, Alpha 2.0, Sample 100, Accs
#  46, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 46, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 46, Alpha 2.0, Sample 200, Accs
#  46, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 46, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 46, Alpha 2.0, Sample 500, Accs
#  46, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 46, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 46, Alpha 2.0, Sample 1000, Accs
#  47, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 47, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 47, Alpha 2.0, Sample 10, Accs
#  47, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 47, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 47, Alpha 2.0, Sample 20, Accs
#  47, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 47, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 47, Alpha 2.0, Sample 50, Accs
#  47, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 47, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 47, Alpha 2.0, Sample 100, Accs
#  47, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 47, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 47, Alpha 2.0, Sample 200, Accs
#  47, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 47, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 47, Alpha 2.0, Sample 500, Accs
#  47, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 47, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 47, Alpha 2.0, Sample 1000, Accs
#  48, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 48, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 48, Alpha 2.0, Sample 10, Accs
#  48, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 48, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 48, Alpha 2.0, Sample 20, Accs
#  48, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 48, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 48, Alpha 2.0, Sample 50, Accs
#  48, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 48, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 48, Alpha 2.0, Sample 100, Accs
#  48, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 48, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 48, Alpha 2.0, Sample 200, Accs
#  48, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 48, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 48, Alpha 2.0, Sample 500, Accs
#  48, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 48, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 48, Alpha 2.0, Sample 1000, Accs
#  49, finetune 2.0, Sample 10, Accs
# ✅ Loaded Seed 49, Alpha 2.0, Sample 10, Losses
# ✅ Loaded Seed 49, Alpha 2.0, Sample 10, Accs
#  49, finetune 2.0, Sample 20, Accs
# ✅ Loaded Seed 49, Alpha 2.0, Sample 20, Losses
# ✅ Loaded Seed 49, Alpha 2.0, Sample 20, Accs
#  49, finetune 2.0, Sample 50, Accs
# ✅ Loaded Seed 49, Alpha 2.0, Sample 50, Losses
# ✅ Loaded Seed 49, Alpha 2.0, Sample 50, Accs
#  49, finetune 2.0, Sample 100, Accs
# ✅ Loaded Seed 49, Alpha 2.0, Sample 100, Losses
# ✅ Loaded Seed 49, Alpha 2.0, Sample 100, Accs
#  49, finetune 2.0, Sample 200, Accs
# ✅ Loaded Seed 49, Alpha 2.0, Sample 200, Losses
# ✅ Loaded Seed 49, Alpha 2.0, Sample 200, Accs
#  49, finetune 2.0, Sample 500, Accs
# ✅ Loaded Seed 49, Alpha 2.0, Sample 500, Losses
# ✅ Loaded Seed 49, Alpha 2.0, Sample 500, Accs
#  49, finetune 2.0, Sample 1000, Accs
# ✅ Loaded Seed 49, Alpha 2.0, Sample 1000, Losses
# ✅ Loaded Seed 49, Alpha 2.0, Sample 1000, Accs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def _err_from_vals(vals, error_type="se"):
    vals = np.asarray(vals, dtype=float)
    mean = float(np.mean(vals))
    std = float(np.std(vals, ddof=1)) if len(vals) > 1 else 0.0
    err = std if error_type == "std" else std / np.sqrt(len(vals))
    return mean, err

def plot_merged_run_and_csv(
    run_data,
    csv_path,
    metric_name,          # key in run_data
    type_val,             # e.g. "train" or "valid" inside dict
    alphas,
    seeds,
    samples,
    csv_metric="valid",   # column in CSV to plot
    csv_mode=None,        # "finetuning" / "multitask" / None
    group_col="scaling",  # grouping column in CSV (like alpha)
    log_x=True,
    use_one_minus_acc=True,
    error_type="se",      # "std" or "se"
):
    assert error_type in {"std", "se"}

    fig, ax = plt.subplots(figsize=(10, 6))

    # separate color palettes to make both sources visible
    run_cmap = plt.colormaps["tab10"] if hasattr(plt, "colormaps") else plt.cm.get_cmap("tab10")
    csv_cmap = plt.colormaps["tab20"] if hasattr(plt, "colormaps") else plt.cm.get_cmap("tab20")

    # --------- RUN_DATA PLOT (alpha curves) ----------
    metric_lower = str(metric_name).lower()
    do_one_minus_run = use_one_minus_acc and ("acc" in metric_lower or "accuracy" in metric_lower)

    for i, alpha in enumerate(alphas):
        means, errs = [], []

        for sample in samples:
            vals = []
            for seed in seeds:
                try:
                    data_matrix = run_data[metric_name][alpha][sample]
                    v = data_matrix[seed]
                    data_dict = v.item() if hasattr(v, "item") else v

                    y = np.max(data_dict[type_val])
                    if do_one_minus_run:
                        y = 1.0 - y
                    vals.append(y)
                except (KeyError, IndexError, TypeError, ValueError):
                    continue

            if len(vals) == 0:
                means.append(np.nan)
                errs.append(np.nan)
            else:
                m, e = _err_from_vals(vals, error_type=error_type)
                means.append(m)
                errs.append(e)

        # If everything is NaN, nothing will appear
        if np.all(np.isnan(means)):
            print(f"[WARN] run_data: α={alpha} produced all-NaN (likely key mismatch / missing data). Skipping.")
            continue

        ax.errorbar(
            samples, means, yerr=errs,
            label=f"run scale={alpha}",
            color=run_cmap(i % 10),
            linestyle="-",
            marker="o",
            linewidth=2.5,
            capsize=4,
            alpha=0.95,
            zorder=3,  # on top
        )

    # --------- CSV PLOT (scaling curves) ----------
    df = pd.read_csv(csv_path)

    # numeric coercion (blank cells -> NaN)
    for c in [csv_metric, group_col, "n_samples"]:
        if c in df.columns:
            df[c] = pd.to_numeric(df[c], errors="coerce")

    if csv_mode is not None and "mode" in df.columns:
        df = df[df["mode"] == csv_mode]

    df = df.dropna(subset=[csv_metric, "n_samples"])

    mlow = str(csv_metric).lower()
    do_one_minus_csv = use_one_minus_acc and (
        "acc" in mlow or "accuracy" in mlow or csv_metric in {"train", "valid"}
    )

    groups = sorted(df[group_col].dropna().unique().tolist())
    x_vals = sorted(df["n_samples"].dropna().unique().tolist())

    for j, g in enumerate(groups):
        means, errs = [], []
        dfg = df[df[group_col] == g]

        for x in x_vals:
            vals = dfg[dfg["n_samples"] == x][csv_metric].dropna().to_numpy()
            if len(vals) == 0:
                means.append(np.nan)
                errs.append(np.nan)
            else:
                if do_one_minus_csv:
                    vals = 1.0 - vals
                m, e = _err_from_vals(vals, error_type=error_type)
                means.append(m)
                errs.append(e)

        if np.all(np.isnan(means)):
            print(f"[WARN] csv: {group_col}={g} produced all-NaN. Skipping.")
            continue

        ax.errorbar(
            x_vals, means, yerr=errs,
            label=f"csv {group_col}={g}",
            color=csv_cmap(j % 20),
            linestyle="--",
            marker="s",
            linewidth=2,
            capsize=4,
            alpha=0.75,
            zorder=2,
        )

    # --------- Styling ----------
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    if log_x:
        ax.set_xscale("log")

    errlab = "Std. Error" if error_type == "se" else "Std. Dev."
    ax.set_title(f"Merged plot (error bars = {errlab})", fontsize=14, pad=12)
    ax.set_xlabel("Sample Size", fontsize=11)
    ax.set_ylabel("Metric", fontsize=11)

    ax.legend(frameon=False, loc="best")
    ax.yaxis.grid(True, linestyle="--", alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
import torch
import numpy as np
from pathlib import Path
seeds = list(range(30))
alphas = [0.01,0.1,0.5,1.0,2,5,10]
 #/nfs/gatsbystor/cdomine/cifar_testing/cifar/main_3/
n_samples=[10, 20, 50, 100, 200, 500, 1000]
#random_seed=0--mode=finetuning--n_samples=10--alpha=1.0--alpha_policy=first_vs_rest--model=resnet
base_path = Path("/nfs/gatsbystor/cdomine/cifar_testing/cifar/extentions_all_pretrain_block_123")
 #base_path = Path("/nfs/nhome/live/cdomine/nested_feature/experiments/cifar/data/cifar/main_3/")
run_data = {
    'losses': {a:{s: [] for s in n_samples} for a in alphas},
    'accs': {a: {s: [] for s in n_samples} for a in alphas},
    'models': {a: {s: [] for s in n_samples} for a in alphas},
    'l2_regs': {a: {s: [] for s in n_samples} for a in alphas}
}
for alpha in alphas:
    for seed in seeds:
        for n_sample in n_samples :
            folder_name = (
                f"random_seed={seed}--mode=finetuning--n_samples={n_sample}--alpha_load={alpha}"
            )
            dir_path = base_path / folder_name
            if dir_path.exists():
                print(f" {seed}, Alpha {alpha}, Sample {n_sample}, Accs"),
                # Load and append data to the lists
                if (dir_path / "losses.npy").exists():
                    run_data['losses'][alpha][n_sample].append(np.load(dir_path / "losses.npy",allow_pickle=True))
                    print(f"✅ Loaded Seed {seed}, Alpha {alpha}, Sample {n_sample}, Losses")
                if (dir_path / "l2_regs.npy").exists():
                    run_data['l2_regs'][alpha][n_sample].append(np.load(dir_path / "l2_regs.npy",allow_pickle=True))
                    print(f"✅ Loaded Seed {seed}, Alpha {alpha}, Sample {n_sample}, l2_regs")
                if (dir_path / "accs.npy").exists():
                    run_data['accs'][alpha][n_sample].append(np.load(dir_path / "accs.npy",allow_pickle=True))
                    print(f"✅ Loaded Seed {seed}, Alpha {alpha}, Sample {n_sample}, Accs"),
            else:
                print(f"Missing directory: {folder_name}")
# Out:
#  0, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 0, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 0, Alpha 0.01, Sample 10, Accs
#  0, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 0, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 0, Alpha 0.01, Sample 20, Accs
#  0, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 0, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 0, Alpha 0.01, Sample 50, Accs
#  0, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 0, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 0, Alpha 0.01, Sample 100, Accs
#  0, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 0, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 0, Alpha 0.01, Sample 200, Accs
#  0, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 0, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 0, Alpha 0.01, Sample 500, Accs
#  0, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 0, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 0, Alpha 0.01, Sample 1000, Accs
#  1, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 1, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 1, Alpha 0.01, Sample 10, Accs
#  1, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 1, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 1, Alpha 0.01, Sample 20, Accs
#  1, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 1, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 1, Alpha 0.01, Sample 50, Accs
#  1, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 1, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 1, Alpha 0.01, Sample 100, Accs
#  1, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 1, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 1, Alpha 0.01, Sample 200, Accs
#  1, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 1, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 1, Alpha 0.01, Sample 500, Accs
#  1, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 1, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 1, Alpha 0.01, Sample 1000, Accs
#  2, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 2, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 2, Alpha 0.01, Sample 10, Accs
#  2, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 2, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 2, Alpha 0.01, Sample 20, Accs
#  2, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 2, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 2, Alpha 0.01, Sample 50, Accs
#  2, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 2, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 2, Alpha 0.01, Sample 100, Accs
#  2, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 2, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 2, Alpha 0.01, Sample 200, Accs
#  2, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 2, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 2, Alpha 0.01, Sample 500, Accs
#  2, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 2, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 2, Alpha 0.01, Sample 1000, Accs
#  3, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 3, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 3, Alpha 0.01, Sample 10, Accs
#  3, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 3, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 3, Alpha 0.01, Sample 20, Accs
#  3, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 3, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 3, Alpha 0.01, Sample 50, Accs
#  3, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 3, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 3, Alpha 0.01, Sample 100, Accs
#  3, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 3, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 3, Alpha 0.01, Sample 200, Accs
#  3, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 3, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 3, Alpha 0.01, Sample 500, Accs
#  3, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 3, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 3, Alpha 0.01, Sample 1000, Accs
#  4, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 4, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 4, Alpha 0.01, Sample 10, Accs
#  4, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 4, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 4, Alpha 0.01, Sample 20, Accs
#  4, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 4, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 4, Alpha 0.01, Sample 50, Accs
#  4, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 4, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 4, Alpha 0.01, Sample 100, Accs
#  4, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 4, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 4, Alpha 0.01, Sample 200, Accs
#  4, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 4, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 4, Alpha 0.01, Sample 500, Accs
#  4, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 4, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 4, Alpha 0.01, Sample 1000, Accs
#  5, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 5, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 5, Alpha 0.01, Sample 10, Accs
#  5, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 5, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 5, Alpha 0.01, Sample 20, Accs
#  5, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 5, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 5, Alpha 0.01, Sample 50, Accs
#  5, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 5, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 5, Alpha 0.01, Sample 100, Accs
#  5, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 5, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 5, Alpha 0.01, Sample 200, Accs
#  5, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 5, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 5, Alpha 0.01, Sample 500, Accs
#  5, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 5, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 5, Alpha 0.01, Sample 1000, Accs
#  6, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 6, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 6, Alpha 0.01, Sample 10, Accs
#  6, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 6, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 6, Alpha 0.01, Sample 20, Accs
#  6, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 6, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 6, Alpha 0.01, Sample 50, Accs
#  6, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 6, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 6, Alpha 0.01, Sample 100, Accs
#  6, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 6, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 6, Alpha 0.01, Sample 200, Accs
#  6, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 6, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 6, Alpha 0.01, Sample 500, Accs
#  6, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 6, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 6, Alpha 0.01, Sample 1000, Accs
#  7, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 7, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 7, Alpha 0.01, Sample 10, Accs
#  7, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 7, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 7, Alpha 0.01, Sample 20, Accs
#  7, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 7, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 7, Alpha 0.01, Sample 50, Accs
#  7, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 7, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 7, Alpha 0.01, Sample 100, Accs
#  7, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 7, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 7, Alpha 0.01, Sample 200, Accs
#  7, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 7, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 7, Alpha 0.01, Sample 500, Accs
#  7, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 7, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 7, Alpha 0.01, Sample 1000, Accs
#  8, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 8, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 8, Alpha 0.01, Sample 10, Accs
#  8, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 8, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 8, Alpha 0.01, Sample 20, Accs
#  8, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 8, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 8, Alpha 0.01, Sample 50, Accs
#  8, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 8, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 8, Alpha 0.01, Sample 100, Accs
#  8, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 8, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 8, Alpha 0.01, Sample 200, Accs
#  8, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 8, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 8, Alpha 0.01, Sample 500, Accs
#  8, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 8, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 8, Alpha 0.01, Sample 1000, Accs
#  9, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 9, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 9, Alpha 0.01, Sample 10, Accs
#  9, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 9, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 9, Alpha 0.01, Sample 20, Accs
#  9, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 9, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 9, Alpha 0.01, Sample 50, Accs
#  9, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 9, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 9, Alpha 0.01, Sample 100, Accs
#  9, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 9, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 9, Alpha 0.01, Sample 200, Accs
#  9, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 9, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 9, Alpha 0.01, Sample 500, Accs
#  9, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 9, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 9, Alpha 0.01, Sample 1000, Accs
#  10, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 10, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 10, Alpha 0.01, Sample 10, Accs
#  10, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 10, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 10, Alpha 0.01, Sample 20, Accs
#  10, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 10, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 10, Alpha 0.01, Sample 50, Accs
#  10, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 10, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 10, Alpha 0.01, Sample 100, Accs
#  10, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 10, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 10, Alpha 0.01, Sample 200, Accs
#  10, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 10, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 10, Alpha 0.01, Sample 500, Accs
#  10, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 10, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 10, Alpha 0.01, Sample 1000, Accs
#  11, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 11, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 11, Alpha 0.01, Sample 10, Accs
#  11, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 11, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 11, Alpha 0.01, Sample 20, Accs
#  11, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 11, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 11, Alpha 0.01, Sample 50, Accs
#  11, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 11, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 11, Alpha 0.01, Sample 100, Accs
#  11, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 11, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 11, Alpha 0.01, Sample 200, Accs
#  11, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 11, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 11, Alpha 0.01, Sample 500, Accs
#  11, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 11, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 11, Alpha 0.01, Sample 1000, Accs
#  12, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 12, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 12, Alpha 0.01, Sample 10, Accs
#  12, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 12, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 12, Alpha 0.01, Sample 20, Accs
#  12, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 12, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 12, Alpha 0.01, Sample 50, Accs
#  12, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 12, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 12, Alpha 0.01, Sample 100, Accs
#  12, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 12, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 12, Alpha 0.01, Sample 200, Accs
#  12, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 12, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 12, Alpha 0.01, Sample 500, Accs
#  12, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 12, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 12, Alpha 0.01, Sample 1000, Accs
#  13, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 13, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 13, Alpha 0.01, Sample 10, Accs
#  13, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 13, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 13, Alpha 0.01, Sample 20, Accs
#  13, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 13, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 13, Alpha 0.01, Sample 50, Accs
#  13, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 13, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 13, Alpha 0.01, Sample 100, Accs
#  13, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 13, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 13, Alpha 0.01, Sample 200, Accs
#  13, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 13, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 13, Alpha 0.01, Sample 500, Accs
#  13, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 13, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 13, Alpha 0.01, Sample 1000, Accs
#  14, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 14, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 14, Alpha 0.01, Sample 10, Accs
#  14, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 14, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 14, Alpha 0.01, Sample 20, Accs
#  14, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 14, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 14, Alpha 0.01, Sample 50, Accs
#  14, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 14, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 14, Alpha 0.01, Sample 100, Accs
#  14, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 14, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 14, Alpha 0.01, Sample 200, Accs
#  14, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 14, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 14, Alpha 0.01, Sample 500, Accs
#  14, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 14, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 14, Alpha 0.01, Sample 1000, Accs
#  15, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 15, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 15, Alpha 0.01, Sample 10, Accs
#  15, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 15, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 15, Alpha 0.01, Sample 20, Accs
#  15, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 15, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 15, Alpha 0.01, Sample 50, Accs
#  15, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 15, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 15, Alpha 0.01, Sample 100, Accs
#  15, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 15, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 15, Alpha 0.01, Sample 200, Accs
#  15, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 15, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 15, Alpha 0.01, Sample 500, Accs
#  15, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 15, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 15, Alpha 0.01, Sample 1000, Accs
#  16, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 16, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 16, Alpha 0.01, Sample 10, Accs
#  16, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 16, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 16, Alpha 0.01, Sample 20, Accs
#  16, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 16, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 16, Alpha 0.01, Sample 50, Accs
#  16, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 16, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 16, Alpha 0.01, Sample 100, Accs
#  16, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 16, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 16, Alpha 0.01, Sample 200, Accs
#  16, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 16, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 16, Alpha 0.01, Sample 500, Accs
#  16, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 16, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 16, Alpha 0.01, Sample 1000, Accs
#  17, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 17, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 17, Alpha 0.01, Sample 10, Accs
#  17, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 17, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 17, Alpha 0.01, Sample 20, Accs
#  17, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 17, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 17, Alpha 0.01, Sample 50, Accs
#  17, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 17, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 17, Alpha 0.01, Sample 100, Accs
#  17, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 17, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 17, Alpha 0.01, Sample 200, Accs
#  17, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 17, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 17, Alpha 0.01, Sample 500, Accs
#  17, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 17, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 17, Alpha 0.01, Sample 1000, Accs
#  18, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 18, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 18, Alpha 0.01, Sample 10, Accs
#  18, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 18, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 18, Alpha 0.01, Sample 20, Accs
#  18, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 18, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 18, Alpha 0.01, Sample 50, Accs
#  18, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 18, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 18, Alpha 0.01, Sample 100, Accs
#  18, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 18, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 18, Alpha 0.01, Sample 200, Accs
#  18, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 18, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 18, Alpha 0.01, Sample 500, Accs
#  18, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 18, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 18, Alpha 0.01, Sample 1000, Accs
#  19, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 19, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 19, Alpha 0.01, Sample 10, Accs
#  19, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 19, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 19, Alpha 0.01, Sample 20, Accs
#  19, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 19, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 19, Alpha 0.01, Sample 50, Accs
#  19, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 19, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 19, Alpha 0.01, Sample 100, Accs
#  19, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 19, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 19, Alpha 0.01, Sample 200, Accs
#  19, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 19, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 19, Alpha 0.01, Sample 500, Accs
#  19, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 19, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 19, Alpha 0.01, Sample 1000, Accs
#  20, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 20, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 20, Alpha 0.01, Sample 10, Accs
#  20, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 20, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 20, Alpha 0.01, Sample 20, Accs
#  20, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 20, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 20, Alpha 0.01, Sample 50, Accs
#  20, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 20, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 20, Alpha 0.01, Sample 100, Accs
#  20, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 20, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 20, Alpha 0.01, Sample 200, Accs
#  20, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 20, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 20, Alpha 0.01, Sample 500, Accs
#  20, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 20, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 20, Alpha 0.01, Sample 1000, Accs
#  21, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 21, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 21, Alpha 0.01, Sample 10, Accs
#  21, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 21, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 21, Alpha 0.01, Sample 20, Accs
#  21, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 21, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 21, Alpha 0.01, Sample 50, Accs
#  21, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 21, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 21, Alpha 0.01, Sample 100, Accs
#  21, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 21, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 21, Alpha 0.01, Sample 200, Accs
#  21, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 21, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 21, Alpha 0.01, Sample 500, Accs
#  21, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 21, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 21, Alpha 0.01, Sample 1000, Accs
#  22, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 22, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 22, Alpha 0.01, Sample 10, Accs
#  22, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 22, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 22, Alpha 0.01, Sample 20, Accs
#  22, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 22, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 22, Alpha 0.01, Sample 50, Accs
#  22, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 22, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 22, Alpha 0.01, Sample 100, Accs
#  22, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 22, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 22, Alpha 0.01, Sample 200, Accs
#  22, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 22, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 22, Alpha 0.01, Sample 500, Accs
#  22, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 22, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 22, Alpha 0.01, Sample 1000, Accs
#  23, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 23, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 23, Alpha 0.01, Sample 10, Accs
#  23, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 23, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 23, Alpha 0.01, Sample 20, Accs
#  23, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 23, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 23, Alpha 0.01, Sample 50, Accs
#  23, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 23, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 23, Alpha 0.01, Sample 100, Accs
#  23, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 23, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 23, Alpha 0.01, Sample 200, Accs
#  23, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 23, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 23, Alpha 0.01, Sample 500, Accs
#  23, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 23, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 23, Alpha 0.01, Sample 1000, Accs
#  24, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 24, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 24, Alpha 0.01, Sample 10, Accs
#  24, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 24, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 24, Alpha 0.01, Sample 20, Accs
#  24, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 24, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 24, Alpha 0.01, Sample 50, Accs
#  24, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 24, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 24, Alpha 0.01, Sample 100, Accs
#  24, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 24, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 24, Alpha 0.01, Sample 200, Accs
#  24, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 24, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 24, Alpha 0.01, Sample 500, Accs
#  24, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 24, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 24, Alpha 0.01, Sample 1000, Accs
#  25, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 25, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 25, Alpha 0.01, Sample 10, Accs
#  25, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 25, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 25, Alpha 0.01, Sample 20, Accs
#  25, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 25, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 25, Alpha 0.01, Sample 50, Accs
#  25, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 25, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 25, Alpha 0.01, Sample 100, Accs
#  25, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 25, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 25, Alpha 0.01, Sample 200, Accs
#  25, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 25, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 25, Alpha 0.01, Sample 500, Accs
#  25, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 25, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 25, Alpha 0.01, Sample 1000, Accs
#  26, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 26, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 26, Alpha 0.01, Sample 10, Accs
#  26, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 26, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 26, Alpha 0.01, Sample 20, Accs
#  26, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 26, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 26, Alpha 0.01, Sample 50, Accs
#  26, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 26, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 26, Alpha 0.01, Sample 100, Accs
#  26, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 26, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 26, Alpha 0.01, Sample 200, Accs
#  26, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 26, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 26, Alpha 0.01, Sample 500, Accs
#  26, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 26, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 26, Alpha 0.01, Sample 1000, Accs
#  27, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 27, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 27, Alpha 0.01, Sample 10, Accs
#  27, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 27, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 27, Alpha 0.01, Sample 20, Accs
#  27, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 27, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 27, Alpha 0.01, Sample 50, Accs
#  27, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 27, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 27, Alpha 0.01, Sample 100, Accs
#  27, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 27, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 27, Alpha 0.01, Sample 200, Accs
#  27, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 27, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 27, Alpha 0.01, Sample 500, Accs
#  27, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 27, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 27, Alpha 0.01, Sample 1000, Accs
#  28, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 28, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 28, Alpha 0.01, Sample 10, Accs
#  28, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 28, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 28, Alpha 0.01, Sample 20, Accs
#  28, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 28, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 28, Alpha 0.01, Sample 50, Accs
#  28, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 28, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 28, Alpha 0.01, Sample 100, Accs
#  28, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 28, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 28, Alpha 0.01, Sample 200, Accs
#  28, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 28, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 28, Alpha 0.01, Sample 500, Accs
#  28, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 28, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 28, Alpha 0.01, Sample 1000, Accs
#  29, Alpha 0.01, Sample 10, Accs
# ✅ Loaded Seed 29, Alpha 0.01, Sample 10, Losses
# ✅ Loaded Seed 29, Alpha 0.01, Sample 10, Accs
#  29, Alpha 0.01, Sample 20, Accs
# ✅ Loaded Seed 29, Alpha 0.01, Sample 20, Losses
# ✅ Loaded Seed 29, Alpha 0.01, Sample 20, Accs
#  29, Alpha 0.01, Sample 50, Accs
# ✅ Loaded Seed 29, Alpha 0.01, Sample 50, Losses
# ✅ Loaded Seed 29, Alpha 0.01, Sample 50, Accs
#  29, Alpha 0.01, Sample 100, Accs
# ✅ Loaded Seed 29, Alpha 0.01, Sample 100, Losses
# ✅ Loaded Seed 29, Alpha 0.01, Sample 100, Accs
#  29, Alpha 0.01, Sample 200, Accs
# ✅ Loaded Seed 29, Alpha 0.01, Sample 200, Losses
# ✅ Loaded Seed 29, Alpha 0.01, Sample 200, Accs
#  29, Alpha 0.01, Sample 500, Accs
# ✅ Loaded Seed 29, Alpha 0.01, Sample 500, Losses
# ✅ Loaded Seed 29, Alpha 0.01, Sample 500, Accs
#  29, Alpha 0.01, Sample 1000, Accs
# ✅ Loaded Seed 29, Alpha 0.01, Sample 1000, Losses
# ✅ Loaded Seed 29, Alpha 0.01, Sample 1000, Accs
#  0, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 0, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 0, Alpha 0.1, Sample 10, Accs
#  0, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 0, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 0, Alpha 0.1, Sample 20, Accs
#  0, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 0, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 0, Alpha 0.1, Sample 50, Accs
#  0, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 0, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 0, Alpha 0.1, Sample 100, Accs
#  0, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 0, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 0, Alpha 0.1, Sample 200, Accs
#  0, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 0, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 0, Alpha 0.1, Sample 500, Accs
#  0, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 0, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 0, Alpha 0.1, Sample 1000, Accs
#  1, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 1, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 1, Alpha 0.1, Sample 10, Accs
#  1, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 1, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 1, Alpha 0.1, Sample 20, Accs
#  1, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 1, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 1, Alpha 0.1, Sample 50, Accs
#  1, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 1, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 1, Alpha 0.1, Sample 100, Accs
#  1, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 1, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 1, Alpha 0.1, Sample 200, Accs
#  1, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 1, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 1, Alpha 0.1, Sample 500, Accs
#  1, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 1, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 1, Alpha 0.1, Sample 1000, Accs
#  2, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 2, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 2, Alpha 0.1, Sample 10, Accs
#  2, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 2, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 2, Alpha 0.1, Sample 20, Accs
#  2, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 2, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 2, Alpha 0.1, Sample 50, Accs
#  2, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 2, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 2, Alpha 0.1, Sample 100, Accs
#  2, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 2, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 2, Alpha 0.1, Sample 200, Accs
#  2, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 2, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 2, Alpha 0.1, Sample 500, Accs
#  2, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 2, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 2, Alpha 0.1, Sample 1000, Accs
#  3, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 3, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 3, Alpha 0.1, Sample 10, Accs
#  3, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 3, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 3, Alpha 0.1, Sample 20, Accs
#  3, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 3, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 3, Alpha 0.1, Sample 50, Accs
#  3, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 3, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 3, Alpha 0.1, Sample 100, Accs
#  3, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 3, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 3, Alpha 0.1, Sample 200, Accs
#  3, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 3, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 3, Alpha 0.1, Sample 500, Accs
#  3, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 3, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 3, Alpha 0.1, Sample 1000, Accs
#  4, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 4, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 4, Alpha 0.1, Sample 10, Accs
#  4, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 4, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 4, Alpha 0.1, Sample 20, Accs
#  4, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 4, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 4, Alpha 0.1, Sample 50, Accs
#  4, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 4, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 4, Alpha 0.1, Sample 100, Accs
#  4, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 4, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 4, Alpha 0.1, Sample 200, Accs
#  4, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 4, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 4, Alpha 0.1, Sample 500, Accs
#  4, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 4, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 4, Alpha 0.1, Sample 1000, Accs
#  5, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 5, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 5, Alpha 0.1, Sample 10, Accs
#  5, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 5, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 5, Alpha 0.1, Sample 20, Accs
#  5, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 5, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 5, Alpha 0.1, Sample 50, Accs
#  5, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 5, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 5, Alpha 0.1, Sample 100, Accs
#  5, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 5, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 5, Alpha 0.1, Sample 200, Accs
#  5, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 5, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 5, Alpha 0.1, Sample 500, Accs
#  5, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 5, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 5, Alpha 0.1, Sample 1000, Accs
#  6, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 6, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 6, Alpha 0.1, Sample 10, Accs
#  6, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 6, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 6, Alpha 0.1, Sample 20, Accs
#  6, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 6, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 6, Alpha 0.1, Sample 50, Accs
#  6, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 6, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 6, Alpha 0.1, Sample 100, Accs
#  6, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 6, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 6, Alpha 0.1, Sample 200, Accs
#  6, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 6, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 6, Alpha 0.1, Sample 500, Accs
#  6, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 6, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 6, Alpha 0.1, Sample 1000, Accs
#  7, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 7, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 7, Alpha 0.1, Sample 10, Accs
#  7, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 7, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 7, Alpha 0.1, Sample 20, Accs
#  7, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 7, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 7, Alpha 0.1, Sample 50, Accs
#  7, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 7, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 7, Alpha 0.1, Sample 100, Accs
#  7, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 7, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 7, Alpha 0.1, Sample 200, Accs
#  7, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 7, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 7, Alpha 0.1, Sample 500, Accs
#  7, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 7, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 7, Alpha 0.1, Sample 1000, Accs
#  8, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 8, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 8, Alpha 0.1, Sample 10, Accs
#  8, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 8, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 8, Alpha 0.1, Sample 20, Accs
#  8, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 8, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 8, Alpha 0.1, Sample 50, Accs
#  8, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 8, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 8, Alpha 0.1, Sample 100, Accs
#  8, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 8, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 8, Alpha 0.1, Sample 200, Accs
#  8, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 8, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 8, Alpha 0.1, Sample 500, Accs
#  8, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 8, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 8, Alpha 0.1, Sample 1000, Accs
#  9, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 9, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 9, Alpha 0.1, Sample 10, Accs
#  9, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 9, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 9, Alpha 0.1, Sample 20, Accs
#  9, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 9, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 9, Alpha 0.1, Sample 50, Accs
#  9, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 9, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 9, Alpha 0.1, Sample 100, Accs
#  9, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 9, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 9, Alpha 0.1, Sample 200, Accs
#  9, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 9, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 9, Alpha 0.1, Sample 500, Accs
#  9, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 9, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 9, Alpha 0.1, Sample 1000, Accs
#  10, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 10, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 10, Alpha 0.1, Sample 10, Accs
#  10, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 10, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 10, Alpha 0.1, Sample 20, Accs
#  10, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 10, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 10, Alpha 0.1, Sample 50, Accs
#  10, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 10, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 10, Alpha 0.1, Sample 100, Accs
#  10, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 10, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 10, Alpha 0.1, Sample 200, Accs
#  10, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 10, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 10, Alpha 0.1, Sample 500, Accs
#  10, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 10, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 10, Alpha 0.1, Sample 1000, Accs
#  11, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 11, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 11, Alpha 0.1, Sample 10, Accs
#  11, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 11, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 11, Alpha 0.1, Sample 20, Accs
#  11, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 11, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 11, Alpha 0.1, Sample 50, Accs
#  11, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 11, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 11, Alpha 0.1, Sample 100, Accs
#  11, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 11, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 11, Alpha 0.1, Sample 200, Accs
#  11, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 11, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 11, Alpha 0.1, Sample 500, Accs
#  11, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 11, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 11, Alpha 0.1, Sample 1000, Accs
#  12, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 12, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 12, Alpha 0.1, Sample 10, Accs
#  12, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 12, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 12, Alpha 0.1, Sample 20, Accs
#  12, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 12, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 12, Alpha 0.1, Sample 50, Accs
#  12, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 12, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 12, Alpha 0.1, Sample 100, Accs
#  12, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 12, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 12, Alpha 0.1, Sample 200, Accs
#  12, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 12, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 12, Alpha 0.1, Sample 500, Accs
#  12, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 12, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 12, Alpha 0.1, Sample 1000, Accs
#  13, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 13, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 13, Alpha 0.1, Sample 10, Accs
#  13, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 13, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 13, Alpha 0.1, Sample 20, Accs
#  13, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 13, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 13, Alpha 0.1, Sample 50, Accs
#  13, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 13, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 13, Alpha 0.1, Sample 100, Accs
#  13, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 13, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 13, Alpha 0.1, Sample 200, Accs
#  13, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 13, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 13, Alpha 0.1, Sample 500, Accs
#  13, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 13, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 13, Alpha 0.1, Sample 1000, Accs
#  14, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 14, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 14, Alpha 0.1, Sample 10, Accs
#  14, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 14, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 14, Alpha 0.1, Sample 20, Accs
#  14, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 14, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 14, Alpha 0.1, Sample 50, Accs
#  14, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 14, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 14, Alpha 0.1, Sample 100, Accs
#  14, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 14, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 14, Alpha 0.1, Sample 200, Accs
#  14, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 14, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 14, Alpha 0.1, Sample 500, Accs
#  14, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 14, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 14, Alpha 0.1, Sample 1000, Accs
#  15, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 15, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 15, Alpha 0.1, Sample 10, Accs
#  15, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 15, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 15, Alpha 0.1, Sample 20, Accs
#  15, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 15, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 15, Alpha 0.1, Sample 50, Accs
#  15, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 15, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 15, Alpha 0.1, Sample 100, Accs
#  15, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 15, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 15, Alpha 0.1, Sample 200, Accs
#  15, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 15, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 15, Alpha 0.1, Sample 500, Accs
#  15, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 15, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 15, Alpha 0.1, Sample 1000, Accs
#  16, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 16, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 16, Alpha 0.1, Sample 10, Accs
#  16, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 16, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 16, Alpha 0.1, Sample 20, Accs
#  16, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 16, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 16, Alpha 0.1, Sample 50, Accs
#  16, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 16, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 16, Alpha 0.1, Sample 100, Accs
#  16, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 16, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 16, Alpha 0.1, Sample 200, Accs
#  16, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 16, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 16, Alpha 0.1, Sample 500, Accs
#  16, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 16, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 16, Alpha 0.1, Sample 1000, Accs
#  17, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 17, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 17, Alpha 0.1, Sample 10, Accs
#  17, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 17, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 17, Alpha 0.1, Sample 20, Accs
#  17, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 17, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 17, Alpha 0.1, Sample 50, Accs
#  17, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 17, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 17, Alpha 0.1, Sample 100, Accs
#  17, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 17, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 17, Alpha 0.1, Sample 200, Accs
#  17, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 17, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 17, Alpha 0.1, Sample 500, Accs
#  17, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 17, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 17, Alpha 0.1, Sample 1000, Accs
#  18, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 18, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 18, Alpha 0.1, Sample 10, Accs
#  18, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 18, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 18, Alpha 0.1, Sample 20, Accs
#  18, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 18, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 18, Alpha 0.1, Sample 50, Accs
#  18, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 18, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 18, Alpha 0.1, Sample 100, Accs
#  18, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 18, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 18, Alpha 0.1, Sample 200, Accs
#  18, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 18, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 18, Alpha 0.1, Sample 500, Accs
#  18, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 18, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 18, Alpha 0.1, Sample 1000, Accs
#  19, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 19, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 19, Alpha 0.1, Sample 10, Accs
#  19, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 19, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 19, Alpha 0.1, Sample 20, Accs
#  19, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 19, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 19, Alpha 0.1, Sample 50, Accs
#  19, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 19, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 19, Alpha 0.1, Sample 100, Accs
#  19, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 19, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 19, Alpha 0.1, Sample 200, Accs
#  19, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 19, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 19, Alpha 0.1, Sample 500, Accs
#  19, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 19, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 19, Alpha 0.1, Sample 1000, Accs
#  20, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 20, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 20, Alpha 0.1, Sample 10, Accs
#  20, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 20, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 20, Alpha 0.1, Sample 20, Accs
#  20, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 20, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 20, Alpha 0.1, Sample 50, Accs
#  20, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 20, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 20, Alpha 0.1, Sample 100, Accs
#  20, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 20, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 20, Alpha 0.1, Sample 200, Accs
#  20, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 20, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 20, Alpha 0.1, Sample 500, Accs
#  20, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 20, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 20, Alpha 0.1, Sample 1000, Accs
#  21, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 21, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 21, Alpha 0.1, Sample 10, Accs
#  21, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 21, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 21, Alpha 0.1, Sample 20, Accs
#  21, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 21, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 21, Alpha 0.1, Sample 50, Accs
#  21, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 21, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 21, Alpha 0.1, Sample 100, Accs
#  21, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 21, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 21, Alpha 0.1, Sample 200, Accs
#  21, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 21, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 21, Alpha 0.1, Sample 500, Accs
#  21, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 21, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 21, Alpha 0.1, Sample 1000, Accs
#  22, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 22, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 22, Alpha 0.1, Sample 10, Accs
#  22, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 22, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 22, Alpha 0.1, Sample 20, Accs
#  22, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 22, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 22, Alpha 0.1, Sample 50, Accs
#  22, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 22, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 22, Alpha 0.1, Sample 100, Accs
#  22, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 22, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 22, Alpha 0.1, Sample 200, Accs
#  22, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 22, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 22, Alpha 0.1, Sample 500, Accs
#  22, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 22, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 22, Alpha 0.1, Sample 1000, Accs
#  23, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 23, Alpha 0.1, Sample 10, Losses
# ✅ Loaded Seed 23, Alpha 0.1, Sample 10, Accs
#  23, Alpha 0.1, Sample 20, Accs
# ✅ Loaded Seed 23, Alpha 0.1, Sample 20, Losses
# ✅ Loaded Seed 23, Alpha 0.1, Sample 20, Accs
#  23, Alpha 0.1, Sample 50, Accs
# ✅ Loaded Seed 23, Alpha 0.1, Sample 50, Losses
# ✅ Loaded Seed 23, Alpha 0.1, Sample 50, Accs
#  23, Alpha 0.1, Sample 100, Accs
# ✅ Loaded Seed 23, Alpha 0.1, Sample 100, Losses
# ✅ Loaded Seed 23, Alpha 0.1, Sample 100, Accs
#  23, Alpha 0.1, Sample 200, Accs
# ✅ Loaded Seed 23, Alpha 0.1, Sample 200, Losses
# ✅ Loaded Seed 23, Alpha 0.1, Sample 200, Accs
#  23, Alpha 0.1, Sample 500, Accs
# ✅ Loaded Seed 23, Alpha 0.1, Sample 500, Losses
# ✅ Loaded Seed 23, Alpha 0.1, Sample 500, Accs
#  23, Alpha 0.1, Sample 1000, Accs
# ✅ Loaded Seed 23, Alpha 0.1, Sample 1000, Losses
# ✅ Loaded Seed 23, Alpha 0.1, Sample 1000, Accs
#  24, Alpha 0.1, Sample 10, Accs
# ✅ Loaded Seed 24, Alpha 0.1, Sample 10, Losses
# ...
# ✅ Loaded Seed 11, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 11, Alpha 10, Sample 100, Accs
#  11, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 11, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 11, Alpha 10, Sample 200, Accs
#  11, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 11, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 11, Alpha 10, Sample 500, Accs
#  11, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 11, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 11, Alpha 10, Sample 1000, Accs
#  12, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 12, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 12, Alpha 10, Sample 10, Accs
#  12, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 12, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 12, Alpha 10, Sample 20, Accs
#  12, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 12, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 12, Alpha 10, Sample 50, Accs
#  12, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 12, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 12, Alpha 10, Sample 100, Accs
#  12, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 12, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 12, Alpha 10, Sample 200, Accs
#  12, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 12, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 12, Alpha 10, Sample 500, Accs
#  12, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 12, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 12, Alpha 10, Sample 1000, Accs
#  13, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 13, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 13, Alpha 10, Sample 10, Accs
#  13, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 13, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 13, Alpha 10, Sample 20, Accs
#  13, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 13, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 13, Alpha 10, Sample 50, Accs
#  13, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 13, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 13, Alpha 10, Sample 100, Accs
#  13, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 13, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 13, Alpha 10, Sample 200, Accs
#  13, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 13, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 13, Alpha 10, Sample 500, Accs
#  13, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 13, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 13, Alpha 10, Sample 1000, Accs
#  14, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 14, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 14, Alpha 10, Sample 10, Accs
#  14, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 14, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 14, Alpha 10, Sample 20, Accs
#  14, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 14, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 14, Alpha 10, Sample 50, Accs
#  14, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 14, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 14, Alpha 10, Sample 100, Accs
#  14, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 14, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 14, Alpha 10, Sample 200, Accs
#  14, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 14, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 14, Alpha 10, Sample 500, Accs
#  14, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 14, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 14, Alpha 10, Sample 1000, Accs
#  15, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 15, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 15, Alpha 10, Sample 10, Accs
#  15, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 15, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 15, Alpha 10, Sample 20, Accs
#  15, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 15, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 15, Alpha 10, Sample 50, Accs
#  15, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 15, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 15, Alpha 10, Sample 100, Accs
#  15, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 15, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 15, Alpha 10, Sample 200, Accs
#  15, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 15, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 15, Alpha 10, Sample 500, Accs
#  15, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 15, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 15, Alpha 10, Sample 1000, Accs
#  16, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 16, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 16, Alpha 10, Sample 10, Accs
#  16, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 16, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 16, Alpha 10, Sample 20, Accs
#  16, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 16, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 16, Alpha 10, Sample 50, Accs
#  16, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 16, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 16, Alpha 10, Sample 100, Accs
#  16, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 16, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 16, Alpha 10, Sample 200, Accs
#  16, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 16, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 16, Alpha 10, Sample 500, Accs
#  16, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 16, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 16, Alpha 10, Sample 1000, Accs
#  17, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 17, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 17, Alpha 10, Sample 10, Accs
#  17, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 17, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 17, Alpha 10, Sample 20, Accs
#  17, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 17, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 17, Alpha 10, Sample 50, Accs
#  17, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 17, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 17, Alpha 10, Sample 100, Accs
#  17, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 17, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 17, Alpha 10, Sample 200, Accs
#  17, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 17, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 17, Alpha 10, Sample 500, Accs
#  17, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 17, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 17, Alpha 10, Sample 1000, Accs
#  18, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 18, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 18, Alpha 10, Sample 10, Accs
#  18, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 18, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 18, Alpha 10, Sample 20, Accs
#  18, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 18, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 18, Alpha 10, Sample 50, Accs
#  18, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 18, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 18, Alpha 10, Sample 100, Accs
#  18, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 18, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 18, Alpha 10, Sample 200, Accs
#  18, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 18, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 18, Alpha 10, Sample 500, Accs
#  18, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 18, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 18, Alpha 10, Sample 1000, Accs
#  19, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 19, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 19, Alpha 10, Sample 10, Accs
#  19, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 19, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 19, Alpha 10, Sample 20, Accs
#  19, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 19, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 19, Alpha 10, Sample 50, Accs
#  19, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 19, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 19, Alpha 10, Sample 100, Accs
#  19, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 19, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 19, Alpha 10, Sample 200, Accs
#  19, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 19, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 19, Alpha 10, Sample 500, Accs
#  19, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 19, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 19, Alpha 10, Sample 1000, Accs
#  20, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 20, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 20, Alpha 10, Sample 10, Accs
#  20, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 20, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 20, Alpha 10, Sample 20, Accs
#  20, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 20, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 20, Alpha 10, Sample 50, Accs
#  20, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 20, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 20, Alpha 10, Sample 100, Accs
#  20, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 20, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 20, Alpha 10, Sample 200, Accs
#  20, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 20, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 20, Alpha 10, Sample 500, Accs
#  20, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 20, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 20, Alpha 10, Sample 1000, Accs
#  21, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 21, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 21, Alpha 10, Sample 10, Accs
#  21, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 21, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 21, Alpha 10, Sample 20, Accs
#  21, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 21, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 21, Alpha 10, Sample 50, Accs
#  21, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 21, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 21, Alpha 10, Sample 100, Accs
#  21, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 21, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 21, Alpha 10, Sample 200, Accs
#  21, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 21, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 21, Alpha 10, Sample 500, Accs
#  21, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 21, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 21, Alpha 10, Sample 1000, Accs
#  22, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 22, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 22, Alpha 10, Sample 10, Accs
#  22, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 22, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 22, Alpha 10, Sample 20, Accs
#  22, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 22, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 22, Alpha 10, Sample 50, Accs
#  22, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 22, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 22, Alpha 10, Sample 100, Accs
#  22, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 22, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 22, Alpha 10, Sample 200, Accs
#  22, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 22, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 22, Alpha 10, Sample 500, Accs
#  22, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 22, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 22, Alpha 10, Sample 1000, Accs
#  23, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 23, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 23, Alpha 10, Sample 10, Accs
#  23, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 23, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 23, Alpha 10, Sample 20, Accs
#  23, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 23, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 23, Alpha 10, Sample 50, Accs
#  23, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 23, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 23, Alpha 10, Sample 100, Accs
#  23, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 23, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 23, Alpha 10, Sample 200, Accs
#  23, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 23, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 23, Alpha 10, Sample 500, Accs
#  23, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 23, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 23, Alpha 10, Sample 1000, Accs
#  24, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 24, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 24, Alpha 10, Sample 10, Accs
#  24, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 24, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 24, Alpha 10, Sample 20, Accs
#  24, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 24, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 24, Alpha 10, Sample 50, Accs
#  24, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 24, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 24, Alpha 10, Sample 100, Accs
#  24, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 24, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 24, Alpha 10, Sample 200, Accs
#  24, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 24, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 24, Alpha 10, Sample 500, Accs
#  24, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 24, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 24, Alpha 10, Sample 1000, Accs
#  25, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 25, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 25, Alpha 10, Sample 10, Accs
#  25, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 25, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 25, Alpha 10, Sample 20, Accs
#  25, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 25, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 25, Alpha 10, Sample 50, Accs
#  25, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 25, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 25, Alpha 10, Sample 100, Accs
#  25, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 25, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 25, Alpha 10, Sample 200, Accs
#  25, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 25, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 25, Alpha 10, Sample 500, Accs
#  25, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 25, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 25, Alpha 10, Sample 1000, Accs
#  26, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 26, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 26, Alpha 10, Sample 10, Accs
#  26, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 26, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 26, Alpha 10, Sample 20, Accs
#  26, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 26, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 26, Alpha 10, Sample 50, Accs
#  26, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 26, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 26, Alpha 10, Sample 100, Accs
#  26, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 26, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 26, Alpha 10, Sample 200, Accs
#  26, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 26, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 26, Alpha 10, Sample 500, Accs
#  26, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 26, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 26, Alpha 10, Sample 1000, Accs
#  27, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 27, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 27, Alpha 10, Sample 10, Accs
#  27, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 27, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 27, Alpha 10, Sample 20, Accs
#  27, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 27, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 27, Alpha 10, Sample 50, Accs
#  27, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 27, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 27, Alpha 10, Sample 100, Accs
#  27, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 27, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 27, Alpha 10, Sample 200, Accs
#  27, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 27, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 27, Alpha 10, Sample 500, Accs
#  27, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 27, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 27, Alpha 10, Sample 1000, Accs
#  28, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 28, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 28, Alpha 10, Sample 10, Accs
#  28, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 28, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 28, Alpha 10, Sample 20, Accs
#  28, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 28, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 28, Alpha 10, Sample 50, Accs
#  28, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 28, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 28, Alpha 10, Sample 100, Accs
#  28, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 28, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 28, Alpha 10, Sample 200, Accs
#  28, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 28, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 28, Alpha 10, Sample 500, Accs
#  28, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 28, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 28, Alpha 10, Sample 1000, Accs
#  29, Alpha 10, Sample 10, Accs
# ✅ Loaded Seed 29, Alpha 10, Sample 10, Losses
# ✅ Loaded Seed 29, Alpha 10, Sample 10, Accs
#  29, Alpha 10, Sample 20, Accs
# ✅ Loaded Seed 29, Alpha 10, Sample 20, Losses
# ✅ Loaded Seed 29, Alpha 10, Sample 20, Accs
#  29, Alpha 10, Sample 50, Accs
# ✅ Loaded Seed 29, Alpha 10, Sample 50, Losses
# ✅ Loaded Seed 29, Alpha 10, Sample 50, Accs
#  29, Alpha 10, Sample 100, Accs
# ✅ Loaded Seed 29, Alpha 10, Sample 100, Losses
# ✅ Loaded Seed 29, Alpha 10, Sample 100, Accs
#  29, Alpha 10, Sample 200, Accs
# ✅ Loaded Seed 29, Alpha 10, Sample 200, Losses
# ✅ Loaded Seed 29, Alpha 10, Sample 200, Accs
#  29, Alpha 10, Sample 500, Accs
# ✅ Loaded Seed 29, Alpha 10, Sample 500, Losses
# ✅ Loaded Seed 29, Alpha 10, Sample 500, Accs
#  29, Alpha 10, Sample 1000, Accs
# ✅ Loaded Seed 29, Alpha 10, Sample 1000, Losses
# ✅ Loaded Seed 29, Alpha 10, Sample 1000, Accs

# %%
plot_merged_run_and_csv(
    run_data=run_data,
    #csv_path="/nfs/nhome/live/cdomine/nested_feature/experiments/cifar/data/cifar/resnet_acc_max.csv",
    csv_path="/nfs/gatsbystor/cdomine/cifar_testing/cifar/resnet_acc_max_main_samscale_sam.csv",
    metric_name="accs",
    type_val="valid",
    alphas = [0.01,0.1,0.5,1.0,2,5,10],
    seeds=list(range(50)),
    samples=[10, 20, 50, 100, 200, 500, 1000],
    csv_metric="valid",
    csv_mode="finetuning",
    error_type="se")

# %%
# This is concatenated with the maximal validation error, we can also run it with the error at the end.
import os
import pandas as pd
import numpy as np
import plotnine as gg
import torch
import numpy as np
from pathlib import Path

base_path = Path("/nfs/gatsbystor/cdomine/cifar_testing/cifar/main_samscale_sam/")

df = []
for folder in os.listdir('/nfs/gatsbystor/cdomine/cifar_testing/cifar/main_samscale_sam/'):
    if 'accs.npy' in os.listdir(f'/nfs/gatsbystor/cdomine/cifar_testing/cifar/main_samscale_sam/{folder}') and\
    (folder.split('--')[1].split('=')[1] != 'finetuning' or len(folder.split('--'))==5):
        new_df = pd.DataFrame({
            k: [v.max()] for k,v in np.load(f'/nfs/gatsbystor/cdomine/cifar_testing/cifar/main_samscale_sam/{folder}/accs.npy', allow_pickle=True)[()].items()\
            if len(v)!=0
            }
        )
        new_df['rs'] = folder.split('--')[0].split('=')[1]
        new_df['mode'] = folder.split('--')[1].split('=')[1]
        new_df['n_samples'] = int(folder.split('--')[2].split('=')[1])
        if folder.split('--')[1].split('=')[1] == 'finetuning':
            new_df['scaling'] = float(folder.split('--')[3].split('=')[1])
        df.append(new_df)
df = pd.concat(df)

df.to_csv('/nfs/gatsbystor/cdomine/cifar_testing/cifar/main_samscale_sam/resnet_acc_max.csv')

(gg.ggplot(df[(df['scaling']==1)|np.isnan(df['scaling'])], gg.aes('n_samples', '1-valid', color='mode')) +
 gg.stat_summary(geom='line') +
 gg.stat_summary(geom='linerange') +
 gg.scale_x_log10() +
 gg.scale_y_log10())
(gg.ggplot(df[df['mode']=='finetuning'], gg.aes('n_samples', '1-valid', color='scaling', group='scaling')) +
 gg.stat_summary(geom='line') +
 gg.stat_summary(geom='linerange') +
 gg.scale_x_log10())
